# %% [markdown]
# Este notebook está vinculado al caso de estudio "Yapo" (ver el [documento](https://docs.google.com/document/d/1SwhwMOyG7-cmzasDeisQZ_NzX5v2VoZ7--lI4UhJz_U/edit#heading=h.5qaqs0frqkx4) de presentación). Se busca construir una base de datos de anuncios en Los Rios recopilando algunos anuncios de Yapo.cl.

# %% [markdown]
# # 1. Construcción de la base de datos

# %%
#!pip install mysql-connector-python

# %%
import mysql.connector 

db_connection = mysql.connector.connect(user="root",host="localhost",password="123qweasd")
cursor = db_connection.cursor()

# %%
cursor.execute("DROP DATABASE Yapo2;")

# %%
cursor.execute("CREATE DATABASE Yapo2;")
cursor.execute("USE Yapo2")

#tabla vendedor
cursor.execute("CREATE TABLE vendedor ("+
               "id_vendedor VARCHAR(130) PRIMARY KEY, nombre VARCHAR(100), ciudad VARCHAR(30), codigo_region VARCHAR(7), "+
               "nombre_region VARCHAR(30), "+
               "fecha_inscripcion DATE)")

#tabla anuncio
cursor.execute("CREATE TABLE anuncio (url VARCHAR(300) PRIMARY KEY, "+
               "titulo VARCHAR(200), descripcion MEDIUMTEXT, precio INT, moneda VARCHAR(2), fecha_publicacion DATE, categoria VARCHAR(50), "
               +"id_vendedor VARCHAR(130), FOREIGN KEY (id_vendedor) REFERENCES vendedor(id_vendedor))")

# %% [markdown]
# # 2. Scrapping de datos para llenar nuestra base de datos Yapo

# %%
#!pip install selenium
#!pip install beautifulsoup4

# %%
from urllib.request import urlopen as uReq
import urllib.request

from bs4 import BeautifulSoup as soup
from selenium import webdriver
import time

# %%
browser = webdriver.Chrome()

myUrl = 'https://www.yapo.cl/chile/todos_los_avisos?ca=12_s&l=0'
#myUrl = 'https://www.yapo.cl/los_rios/todos_los_avisos?ca=11_s&l=0&w=1&cmn=243'
browser.get(myUrl)

# %%
pageSoup = soup(browser.page_source, 'html.parser')

pages = pageSoup.find('span',  {'class', 'nohistory FloatRight'}).a['href']

# %%
pages
# Out:
# 'https://www.yapo.cl/chile?ca=12_s&o=28101'

# %%
index = pages.rfind('=')
print(index)
lastPage = int(pages[index+1:])
print(lastPage)
root_pages = pages[:index+1]
print(root_pages)
# Out:
# 35
# 28101
# https://www.yapo.cl/chile?ca=12_s&o=

# %%
import datetime

def convert_date(yapo_date):
    month=yapo_date.split(" ")[0]
    year=yapo_date.split(" ")[1]
    
    convert = {'Enero' : 1,
            'Febrero' : 2,
            'Marzo' : 3,
            'Abril' : 4,
            'Mayo' : 5,
            'Junio' : 6,
            'Julio' : 7,
            'Agosto' : 8,
            'Septiembre' : 9, 
            'Octubre' : 10,
            'Noviembre' : 11,
            'Diciembre' : 12
           }
    
    
    new_date=datetime.date(int(year), convert[month], 1) 

    return new_date

print(convert_date("Febrero 2020"))
# Out:
# 2020-02-01

# %%
for i in range(lastPage):
    
    #recuperarmos la URL de la pagina corriente
    url = root_pages + str(i+1)
    
    #con Selenium, vamos en navegar en esta página
    browser.get(url)
    
    #empezamos el scrapping de la pagina corriente
    pageSoup = soup(browser.page_source, 'html.parser')
    
    #recuperamos todos los tags HTML que corresponden a la lista de anuncios en esta pagina
    links = pageSoup.findAll('td', {'class' : 'thumbs_subject'})
    
    #empezamos a iterar sobre cada anuncio
    for link in links:
        
        #todos los datos que necesitamos encontrar
        url, titulo, descripcion, precio, fecha_publicacion, categoria="","","",None,"", ""
        nombre, ciudad, codigo_region, nombre_region, fecha_inscripcion="","","","",""
        
        #Navegamos hacia la pagina del anuncio
        url=link.find('a',{'class':'title'})['href']
        print(url)
        browser.get(link.find('a',{'class':'title'})['href'])

        #RECUPERAMOS LA FECHA DE PUBLICACION DEL ANUNCIO          
        pageSoup = soup(browser.page_source, 'html.parser')
        if(pageSoup.find('time')):
            datetime_raw = pageSoup.find('time').attrs['datetime']
            date_publication_raw=datetime_raw.split("T")[0]
            date_publication_raw=  date_publication_raw.split("-")
            
            date_publication=datetime.date(int(date_publication_raw[0]), int(date_publication_raw[1]),
                                           int(date_publication_raw[2]))
            print("datetime:")
            print(date_publication)
        
        #RECUPERAMOS EL TITULO DEL ANUNCIO           
        pageSoup = soup(browser.page_source, 'html.parser')
        if(pageSoup.find('h1', {"id" : "da_subject"})):
            titulo = pageSoup.find('h1', {"id" : "da_subject"}).text.strip()
            print(titulo)
            
        #RECUPERAMOS LA DESCRIPCION DEL ANUNCIO
        if(pageSoup.find('div', {"class" : "description"})):
            try:
                descripcion = pageSoup.find('div', {"class" : "description"}).text.split(' ', 1)[1].strip().replace(u'\n', u' ')
            except:
                continue
                
        #RECUPERAMOS EL PRECIO DEL ANUNCIO
        if(pageSoup.find('div', {"class" : "price text-right"})):
            precio_raw = pageSoup.find('div', {"class" : "price text-right"}).text.strip().replace(u'\n', u' ').replace(u'\t', u'')
            precio_raw = precio_raw.split(" ")
            moneda = precio_raw[0]
            precio = precio_raw[1].split(",")[0].replace(u'.', u'')
            print("precio:"+precio)
            
        #RECUPERAMOS LA CATEGORIA DEL ANUNCIO
        if(pageSoup.find('div', {"class" : "breadcrumbs"})):
            categoria = pageSoup.find('div', {"class" : "breadcrumbs"}).find('a', {"id" : "breadcrumb_category"}).find('strong').text.strip().replace(u'\n', u' ')
            print(categoria)
            
        
        #RECUPERAMOS EL NOMBRE DEL VENDEDOR, SU FECHA DE INSCRIPCION Y SU LOCALIDAD
        if(pageSoup.find('aside', {"class" : "sidebar-right"})):
            aside = pageSoup.find('aside', {"class" : "sidebar-right"})
    
            #print(aside.find('seller-info'))
            
            #NOMBRE
            if(aside.find('seller-info')!=None):
                nombre=aside.find('seller-info').attrs['username']
            
                #FECHA DE INSCRIPCION
                fecha_inscripcion_raw=aside.find('seller-info').attrs['seniority']
                try:
                    fecha_inscripcion_raw=fecha_inscripcion_raw[len("En Yapo desde "):]
                    fecha_inscripcion=convert_date(fecha_inscripcion_raw)
                    print(fecha_inscripcion)
                except:
                    fecha_inscripcion=None
                    continue
                
                #LOCALIDAD
                localidad_raw=aside.find('seller-info').attrs['region']
            
                #print(localidad_raw)
            
                region_raw=localidad_raw.split(",")[0]
                ciudad_raw=localidad_raw.split(",")[1]
            
                codigo_region=region_raw.split(" ")[0]
                nombre_region=region_raw[len(codigo_region)+1:]
                ciudad=ciudad_raw[1:]
                
        # LLENAMOS LA BASE DE DATOS: TABLA VENDEDOR
        
        try:
            sql = "INSERT INTO vendedor (id_vendedor,nombre, ciudad, codigo_region, nombre_region, fecha_inscripcion) VALUES (%s,%s, %s, %s,%s,%s)"
            val = (nombre+"_"+codigo_region+"_"+ciudad,nombre, ciudad, codigo_region, nombre_region, fecha_inscripcion)
            cursor.execute(sql, val)
        except Exception as e1:
            print(e1)
            #continue
        
        # LLENAMOS LA BASE DE DATOS: TABLA ANUNCIO
        try:
            sql = "INSERT INTO anuncio (url, titulo, descripcion, precio, moneda, fecha_publicacion, categoria, id_vendedor) VALUES (%s, %s, %s,%s, %s, %s, %s, %s)"
            val = (url, titulo, descripcion, int(precio), moneda, date_publication, categoria, nombre+"_"+codigo_region+"_"+ciudad)
            cursor.execute(sql, val)
        except Exception as e2:
            print(e2)
            #continue
        
        cursor.execute("COMMIT")
# Out:
# https://www.yapo.cl/biobio/muebles/galon_con_jaula_74038322.htm?ca=9_s&first=1&oa=74038322&xsp=0
# datetime:
# 2020-08-29
# Galón con jaula
# precio:30000
# Muebles
# 2014-12-01
# https://www.yapo.cl/maule/animales_accesorios/montura_cordillerana_nueva_74038321.htm?ca=8_s&oa=74038321&xsp=1
# datetime:
# 2020-08-29
# Montura Cordillerana nueva
# precio:440000
# Animales y sus accesorios
# 2015-10-01
# https://www.yapo.cl/antofagasta/consolas_videojuegos/wii_u_controles_y_accesorios_74038320.htm?ca=3_s&oa=74038320&xsp=2
# datetime:
# 2020-08-29
# Wii U controles y accesorios
# precio:15000
# Consolas, videojuegos y accesorios
# 2016-05-01
# https://www.yapo.cl/region_metropolitana/juguetes/nerf_zombie_74038319.htm?ca=15_s&oa=74038319&xsp=3
# datetime:
# 2020-08-29
# Nerf zombie
# precio:5000
# Juguetes
# 2015-05-01
# https://www.yapo.cl/region_metropolitana/libros_revistas/the_walking_dead_el_gobernador_74038318.htm?ca=15_s&oa=74038318&xsp=4
# datetime:
# 2020-08-29
# The walking dead El gobernador
# precio:8000
# Libros y revistas
# 2019-12-01
# https://www.yapo.cl/region_metropolitana/celulares/samsung_galaxy_young__conversable__74038317.htm?ca=15_s&oa=74038317&xsp=5
# datetime:
# 2020-08-29
# Samsung Galaxy Young (conversable)
# precio:29000
# Celulares, teléfonos y accesorios
# 2014-10-01
# https://www.yapo.cl/coquimbo/salud-belleza/fajas_quemadoras_de_grasa_reduce_tallas__74038316.htm?ca=5_s&oa=74038316&xsp=6
# datetime:
# 2020-08-29
# Fajas quemadoras de grasa reduce tallas
# precio:7000
# Salud y belleza
# 2020-01-01
# https://www.yapo.cl/biobio/bolsos-bisuteria-accesorios/mochila_saxoline_74038315.htm?ca=9_s&oa=74038315&xsp=7
# datetime:
# 2020-08-29
# Mochila saxoline
# precio:2500
# Bolsos, bisutería y accesorios
# 2019-12-01
# https://www.yapo.cl/valparaiso/motos/honda_cb190r_74038314.htm?ca=6_s&oa=74038314&xsp=8
# datetime:
# 2020-08-29
# Honda cb190r
# precio:1500000
# Motos
# 2015-01-01
# https://www.yapo.cl/magallanes_antartica/articulos-del-hogar/set_de_3_cortinas_x_74038313.htm?ca=14_s&oa=74038313&xsp=9
# datetime:
# 2020-08-29
# Set de 3 cortinas x
# precio:15000
# datetime:
# 2020-08-29
# Collar plata 925
# precio:16990
# Bolsos, bisutería y accesorios
# 2015-02-01
# https://www.yapo.cl/region_metropolitana/celulares/aro_de_luz_de_42cm_con_tripode_1_90cm_new_74038301.htm?ca=15_s&oa=74038301&xsp=23
# datetime:
# 2020-08-29
# Aro de luz de 42cm con trípode 1.90cm new
# precio:70000
# Celulares, teléfonos y accesorios
# 2017-05-01
# https://www.yapo.cl/region_metropolitana/jardin_herramientas/mueble_terrazas_mimbre_74038300.htm?ca=15_s&oa=74038300&xsp=24
# datetime:
# 2020-08-29
# Mueble terrazas mimbre
# precio:250000
# Jardín, herramientas y exteriores
# 2019-03-01
# https://www.yapo.cl/region_metropolitana/autos/suzuki_swift_2007_74038299.htm?ca=15_s&oa=74038299&xsp=25
# datetime:
# 2020-08-29
# Suzuki swift 2007
# precio:2550000
# Autos, camionetas y 4x4
# 2020-08-01
# https://www.yapo.cl/region_metropolitana/articulos-del-hogar/toalla_premium_beku_74038298.htm?ca=15_s&oa=74038298&xsp=26
# datetime:
# 2020-08-29
# Toalla premium beku
# precio:8990
# Otros artículos del hogar
# 2020-08-01
# https://www.yapo.cl/los_rios/busco_empleo/persona_responsable_74038297.htm?ca=11_s&oa=74038297&xsp=27
# datetime:
# 2020-08-29
# Persona responsable
# Busco empleo
# 2019-09-01
# int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# https://www.yapo.cl/region_metropolitana/television_camaras/audifonos_campfire_andromeda_74038296.htm?ca=15_s&oa=74038296&xsp=28
# datetime:
# 2020-08-29
# Audifonos Campfire Andromeda
# precio:700000
# Audio, TV, video y fotografía
# 2015-06-01
# https://www.yapo.cl/region_metropolitana/muebles/cama_plaza_y_media__antigua_estilo_normando_74038295.htm?ca=15_s&oa=74038295&xsp=29
# datetime:
# 2020-08-29
# Cama plaza y media, antigua estilo normando
# Muebles
# 2019-02-01
# int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# https://www.yapo.cl/maule/autos/corsa_plus_full_equipo__74038294.htm?ca=8_s&oa=74038294&xsp=30
# datetime:
# 2020-08-29
# corsa plus full equipo
# precio:2150000
# Autos, camionetas y 4x4
# 2015-03-01
# https://www.yapo.cl/region_metropolitana/accesorios_vehiculos/permuto_casco_nuevo_74038293.htm?ca=15_s&oa=74038293&xsp=31
# datetime:
# 2020-08-29
# Permuto casco nuevo
# precio:95000
# Accesorios y piezas para vehículos
# 2013-11-01
# https://www.yapo.cl/region_metropolitana/muebles/rosen_colchon_king_74038292.htm?ca=15_s&oa=74038292&xsp=32
# datetime:
# 2020-08-29
# Rosen Colchon king
# precio:80000
# Muebles
# 2019-12-01
# https://www.yapo.cl/region_metropolitana/moda-vestuario/abrigo_americanino_74038291.htm?ca=15_s&oa=74038291&xsp=33
# datetime:
# 2020-08-29
# Abrigo Americanino
# precio:12000
# Moda y vestuario
# 2016-04-01
# 1062 (23000): Duplicate entry 'Natalia_Región_Maipú' for key 'PRIMARY'
# https://www.yapo.cl/ohiggins/arte_antiguedades_colecciones/carruaje_frances__74038290.htm?ca=7_s&oa=74038290&xsp=34
# datetime:
# 2020-08-29
# Carruaje francés
# precio:4000000
# Arte, antigüedades y colecciones
# 2014-07-01
# https://www.yapo.cl/region_metropolitana/animales_accesorios/caballo_inscrito__74038289.htm?ca=15_s&oa=74038289&xsp=35
# datetime:
# 2020-08-29
# Caballo inscrito
# precio:1000000
# Animales y sus accesorios
# 2014-05-01
# https://www.yapo.cl/region_metropolitana
01
# int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# https://www.yapo.cl/region_metropolitana/arrendar/3d_y_1b_gc_incluidos__metro_lo_vial__san_miguel_71304626.htm?ca=15_s&oa=71304626&xsp=0
# datetime:
# 2020-08-29
# 3D y 1B GC Incluidos, Metro Lo Vial, San Miguel
# precio:360000
# Arriendo - Departamento
# 2014-06-01
# https://www.yapo.cl/region_metropolitana/arrendar/hermosa_casa_en_valle_norte_a_70291131.htm?ca=15_s&oa=70291131&xsp=1
# datetime:
# 2020-08-29
# Hermosa Casa en Valle Norte a
# precio:350000
# Arriendo - Casa
# 2014-06-01
# https://www.yapo.cl/region_metropolitana/arrendar/depto_2d_y_1b_metro_las_rejas_69897809.htm?ca=15_s&oa=69897809&xsp=2
# datetime:
# 2020-08-29
# Depto 2D y 1B Metro Las Rejas
# precio:260000
# Arriendo - Departamento
# 2014-06-01
# https://www.yapo.cl/region_metropolitana/autos/busco__kia_motors_rio_2014_chocado_volcado_en_todo_el_pai_67284391.htm?ca=15_s&oa=67284391&xsp=3
# datetime:
# 2020-08-29
# Busco: Kia motors rio 2014 CHOCADO VOLCADO EN TODO EL PAI
# precio:3000000
# Autos, camionetas y 4x4
# 2014-01-01
# https://www.yapo.cl/region_metropolitana/arrendar/depto_1_dormitorio_frente_parque_araucano_73952415.htm?ca=15_s&oa=73952415&xsp=4
# datetime:
# 2020-08-29
# Depto.1 dormitorio frente Parque Araucano
# precio:450000
# Arriendo - Departamento
# 2014-07-01
# https://www.yapo.cl/region_metropolitana/autos/opel_insignia_opc_como_nuevo_73950129.htm?ca=15_s&oa=73950129&xsp=5
# datetime:
# 2020-08-29
# OPEL INSIGNIA OPC como NUEVO
# precio:12499000
# Autos, camionetas y 4x4
# 2015-05-01
# https://www.yapo.cl/region_metropolitana/arrendar/local_frente_metro_plaza_puente_alto_73809859.htm?ca=15_s&oa=73809859&xsp=6
# datetime:
# 2020-08-29
# Local frente Metro Plaza Puente Alto
# precio:170
# Arriendo - Comercial e industrial
# 2014-07-01
# https://www.yapo.cl/ohiggins/comprar/parcela_de_agrado_bucalemu_73971443.htm?ca=7_s&oa=73971443&xsp=7
# datetime:
# 2020-08-29
# Parcela de Agrado Bucalemu
# precio:8990000
# Vendo - Terreno
# 2014-06-01
# https://www.yapo.cl/region_metropolitana/autos/suzuki_grand_nomade_2017_con_adicionales_73784271.htm?ca=15_s&oa=73784271&xsp=8
# datetime:
# 2020-08-29
# SUZUKI GRAND NOMADE 2017 con adicionales
# precio:8390000
# Autos, camionetas y 4x4
# 2013-11-01
# https://www.yapo.cl/region_metropolitana/autos/bmw_320d_71381695.htm?ca=15_s&oa=71381695&xsp=9
# datetime:
# 2020-08-29
# Bmw 320d
# precio:8900000
# Autos, camionetas y 4x4
# 2014-05-01
# https://www.yapo.cl/region_metropolitana/arte_antiguedades_colecciones/cuadro_antiguo_boliviano_autor_desconocido_74038449.htm?ca=15_s&oa=74038449&xsp=10
# datetime:
# 2020-08-29
# Cuadro Antiguo boliviano autor desconocido
# precio:3000000
# Arte, antigüedades y colecciones
# 2014-12-01
# https://www.yapo.cl/region_metropolitana/autos/mitsubishi_l200_2016_74024327.htm?ca=15_s&oa=74024327&xsp=11
# datetime:
# 2020-08-29
# Mitsubishi l200 2016
# precio:12900000
# Autos, camionetas y 4x4
# 2020-04-01
# https://www.yapo.cl/maule/autos/nissan_tiida_2011_74008304.htm?ca=8_s&oa=74008304&xsp=12
# datetime:
# 2020-08-29
# Nissan tiida 2011
# precio:3400000
# Autos, camionetas y 4x4
# 2018-11-01
# https://www.yapo.cl/region_metropolitana/comprar/terreno_sector_privilegiado_talagante_74007979.htm?ca=15_s&oa=74007979&xsp=13
# datetime:
# 2020-08-29
# Terreno Sector Privilegiado Talagante
# precio:1220
# Vendo - Terreno
# 2020-06-01
# https://www.yapo.cl/region_metropolitana/ofertas_de_empleo/repartidor_73990581.htm?ca=15_s&oa=73990581&xsp=14
# datetime:
# 2020-08-29
# Repartidor
# Ofertas de empleo
# 2017-10-01
# int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# https://www.yapo.cl/region_metropolitana/muebles/comedor_madera_alerce_oregon_73990362.htm?ca=15_s&oa=73990362&xsp=15
# datetime:
# 2020-08-29
# Comedor madera alerce oregón
# precio:390000
# Muebles
# 2020-07-01
# https://www.yapo.cl/region_metropolitana/ofertas_de_empleo/repartidor_en_motocicleta_73990259.htm?ca=15_s&oa=73990259&xsp=16
# datetime:
# 2020-08-29
# Repartidor en Motocicleta
# precio:240000
# Ofertas de empleo
# 2020-08-01
# https://www.yapo.cl/region_metropolitana/arrendar/oficina_en_providencia_73990175.htm?ca=15_s&oa=73990175&xsp=17
# datetime:
# 2020-08-29
# oficina en providencia
# precio:8
# Arriendo - Oficina
# 2018-05-01
# https://www.yapo.cl/region_metropolitana/arrendar/casa_en_parcela_73971925.htm?ca=15_s&oa=73971925&xsp=18
# datetime:
# 2020-08-29
# Casa en parcela
# precio:550000
# Arriendo - Casa
# 2015-08-01
# https://www.yapo.cl/region_metropolitana/servicios/arriendo_de_maquinaria_pesada_73971622.htm?ca=15_s&oa=73971622&xsp=19
# datetime:
# 2020-08-29
# arriendo de maquinaria pesada
# Servicios
# 2020-08-01
# int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# https://www.yapo.cl/ohiggins/comprar/parcelas_bucalemu_rol_propio_73970800.htm?ca=7_s&oa=73970800&xsp=20
# datetime:
# 2020-08-29
# Parcelas Bucalemu ROL Propio
# precio:7990000
# Vendo - Terreno
# 2014-06-01
# https://www.yapo.cl/region_metropolitana/ofertas_de_empleo/agente_de_soporte_y_post_venta_73953281.htm?ca=15_s&oa=73953281&xsp=21
# datetime:
# 2020-08-29
# agente de soporte y post-venta
# Ofertas de empleo
# 2018-05-01
# int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# https://www.yapo.cl/araucania/autos/mitsubishi_l200_2011_73952988.htm?ca=10_s&oa=73952988&xsp=22
# datetime:
# 2020-08-29
# Mitsubishi l200 2011
# precio:9200000
# Autos, camionetas y 4x4
# 2013-11-01
# https://www.yapo.cl/region_metropolitana/arrendar/departamento_73952692.htm?ca=15_s&oa=73952692&xsp=23
# datetime:
# 2020-08-29
# Departamento
# precio:330000
# Arriendo - Departamento
# 2018-12-01
# https://www.yapo.cl/region_metropolitana/salud-belleza/insumos_tiras_accu_chek_diabetes_73952683.htm?ca=15_s&oa=73952683&xsp=24
# datetime:
# 2020-08-29
# Insumos tiras accu-chek diabetes
# precio:1000
# Salud y belleza
# 2020-08-01
# https://www.yapo.cl/region_metropolitana/arrendar/departamento_sin_comision__garantia_en_cuotas_73952468.htm?ca=15_s&oa=73952468&xsp=25
# datetime:
# 2020-08-29
# Departamento Sin Comisión, Garantía en cuotas
# precio:330000
# Arriendo - Departamento
# 2018-12-01
# https://www.yapo.cl/region_metropolitana/arrendar/arriendo_depto__garantia_y_comision_en_cuotas_73951885.htm?ca=15_s&oa=73951885&xsp=26
# datetime:
# 2020-08-29
# Arriendo Depto, Garantía y Comisión en cuotas
# precio:340000
# Arriendo - Departamento
# 2018-12-01
# 1062 (23000): Duplicate entry 'Alba Karina Martinez Ramirez_Región_Estación Central' for key 'PRIMARY'
# https://www.yapo.cl/region_metropolitana/ofertas_de_empleo/disenador_grafico_leer_descripcion_importante_73934525.htm?ca=15_s&oa=73934525&xsp=27
# datetime:
# 2020-08-29
# Diseñador grafico leer descripción importante
# Ofertas de empleo
# 2020-08-01
# int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# https://www.yapo.cl/magallanes_antartica/autos/cruze_2_0_ltz_73932964.htm?ca=14_s&oa=73932964&xsp=28
# datetime:
# 2020-08-29
# Cruze 2.0 LTZ
# precio:5290000
# Autos, camionetas y 4x4
# 2014-08-01
# https://www.yapo.cl/valparaiso/ofertas_de_empleo/maestros_linieros_73918129.htm?ca=6_s&oa=73918129&xsp=29
# datetime:
# 2020-08-29
# Maestros linieros
# Ofertas de empleo
# 2017-04-01
# int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# https://www.yapo.cl/region_metropolitana/autos/chevrolet_sail_para_repuesto__73914553.htm?ca=15_s&oa=73914553&xsp=30
# datetime:
# 2020-08-29
# Chevrolet sail para repuesto
# Autos, camionetas y 4x4
# 2020-08-01
# int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# https://www.yapo.cl/region_metropolitana/articulos-del-hogar/busco_galon_de_gas__73912653.htm?ca=15_s&oa=73912653&xsp=31
# datetime:
# 2020-08-29
# busco Galón de gas
# precio:20000
# Otros artículos del hogar
# https://www.yapo.cl/region_metropolitana/autos/mazda_cx5_2015_73829391.htm?ca=15_s&oa=73829391&xsp=32
# datetime:
# 2020-08-29
# Mazda cx5 2015
# precio:9600000
# Autos, camionetas y 4x4
# 2017-06-01
# https://www.yapo.cl/tarapaca/autos/hyundai_santa_fe_2016_73688265.htm?ca=2_s&oa=73688265&xsp=33
# datetime:
# 2020-08-29
# Hyundai santa fe 2016
# precio:9900000
# Autos, camionetas y 4x4
# 2014-06-01
# https://www.yapo.cl/region_metropolitana/arrendar/departamento_amoblado_maipu_73460555.htm?ca=15_s&oa=73460555&xsp=34
# datetime:
# 2020-08-29
# Departamento amoblado Maipú
# precio:420000
# Arriendo - Departamento
# 2014-06-01
# https://www.yapo.cl/region_metropolitana/arrendar/depto_3d_y_1b_independencia__73030565.htm?ca=15_s&oa=73030565&xsp=35
# datetime:
# 2020-08-29
# Depto 3D y 1B Independencia
# precio:350000
# Arriendo - Departamento
# 2014-06-01
# https://www.yapo.cl/region_metropolitana/arrendar/depto_2d_y_2b___bodeg_metro_sta_isabel_72571513.htm?ca=15_s&oa=72571513&xsp=36
# datetime:
# 2020-08-29
# Depto 2D y 2B + Bodeg Metro Sta Isabel
# precio:390000
# Arriendo - Departamento
# 2014-06-01
# https://www.yapo.cl/region_metropolitana/arrendar/departamento_metro_cal_y_canto_72440265.htm?ca=15_s&oa=72440265&xsp=37
# datetime:
# 2020-08-29
# Departamento metro Cal y Canto
# precio:250000
# Arriendo - Departamento
# 2014-06-01
# 1062 (23000): Duplicate entry 'Corredores Abogados Propiedades_Región_Santiago' for key 'PRIMARY'
# https://www.yapo.cl/coquimbo/servicios/tratamiento_ceramico_72352240.htm?ca=5_s&oa=72352240&xsp=38
# datetime:
# 2020-08-29
# Tratamiento ceramico
# precio:160000
# Servicios
# 2016-03-01
# https://www.yapo.cl/region_metropolitana/camiones_furgones/hyundai_new_h1_gls_crdi_2_5_ano_2016_71779294.htm?ca=15_s&oa=71779294&xsp=39
01
# int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# https://www.yapo.cl/araucania/camiones_furgones/sprinter_313_15__1_full_74038439.htm?ca=10_s&oa=74038439&xsp=0
# datetime:
# 2020-08-29
# Sprinter 313 15 +1 full
# precio:9500000
# Buses, camiones y furgones
# 2014-05-01
# https://www.yapo.cl/los_lagos/deportes_gimnasia/botas_de_snowboard_nitro_74038438.htm?ca=12_s&oa=74038438&xsp=1
# datetime:
# 2020-08-29
# Botas de Snowboard NITRO
# precio:80000
# Deportes, gimnasia y accesorios
# 2019-05-01
# https://www.yapo.cl/atacama/accesorios_vehiculos/turbo_toyota_hi_lux_3_0_74038437.htm?ca=4_s&oa=74038437&xsp=2
# datetime:
# 2020-08-29
# Turbo Toyota Hi Lux 3.0
# precio:280000
# Accesorios y piezas para vehículos
# 2015-08-01
# https://www.yapo.cl/atacama/accesorios_vehiculos/bomba_direccion_toyota_hilux_3_0_74038436.htm?ca=4_s&oa=74038436&xsp=3
# datetime:
# 2020-08-29
# Bomba Direccion Toyota Hilux 3.0
# precio:80000
# Accesorios y piezas para vehículos
# 2015-08-01
# 1062 (23000): Duplicate entry 'jorge_III_Copiapó' for key 'PRIMARY'
# https://www.yapo.cl/region_metropolitana/moda-vestuario/panuelo_flores_74038435.htm?ca=15_s&oa=74038435&xsp=4
# datetime:
# 2020-08-29
# Pañuelo flores
# precio:4000
# Moda y vestuario
# 2014-01-01
# https://www.yapo.cl/los_lagos/accesorios_vehiculos/neumaticos_ford_raptor__74038434.htm?ca=12_s&oa=74038434&xsp=5
# datetime:
# 2020-08-29
# Neumáticos ford raptor
# Accesorios y piezas para vehículos
# 2015-11-01
# int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# https://www.yapo.cl/biobio/salud-belleza/set_manicure_74038433.htm?ca=9_s&oa=74038433&xsp=6
# datetime:
# 2020-08-29
# Set manicure
# Salud y belleza
# 2019-12-01
# 1062 (23000): Duplicate entry 'sebabeltrane_VIII_San Pedro de la Paz' for key 'PRIMARY'
# int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# https://www.yapo.cl/maule/autos/kia_motors_sportage_lx_2_0l_4x4__74038432.htm?ca=8_s&oa=74038432&xsp=7
# datetime:
# 2020-08-29
# KIA MOTORS SPORTAGE LX 2.0L 4X4
# precio:5500000
# Autos, camionetas y 4x4
# https://www.yapo.cl/araucania/bicicletas_ciclismo/bicicleta_oxford_mujer_74038431.htm?ca=10_s&oa=74038431&xsp=8
# datetime:
# 2020-08-29
# Bicicleta oxford mujer
# precio:95000
# Bicicletas, ciclismo y accesorios
# 2014-12-01
# https://www.yapo.cl/region_metropolitana/moda-vestuario/chaqueta_zooyork_74038430.htm?ca=15_s&oa=74038430&xsp=9
# datetime:
# 2020-08-29
# Chaqueta ZooYork
# precio:40000
# Moda y vestuario
# 2016-03-01
# https://www.yapo.cl/arica_parinacota/vestuario-futura-mama-ninos/traje_huasito_74038428.htm?ca=1_s&oa=74038428&xsp=10
# datetime:
# 2020-08-29
# Traje huasito
# precio:20000
# Vestuario futura mamá y niños
# 2014-02-01
# https://www.yapo.cl/region_metropolitana/muebles/mesa_de_centro_74038427.htm?ca=15_s&oa=74038427&xsp=11
# datetime:
# 2020-08-29
# Mesa de centro
# precio:40000
# Muebles
# 2014-06-01
# https://www.yapo.cl/ohiggins/moda-vestuario/cortavientos_dama_talla_42_muy_liviana_74038426.htm?ca=7_s&oa=74038426&xsp=12
# datetime:
# 2020-08-29
# Cortavientos dama talla 42 muy liviana
# precio:7000
# Moda y vestuario
# 2017-07-01
# https://www.yapo.cl/valparaiso/otros_vehiculos/semi_remolque_73666137.htm?ca=6_s&oa=73666137&xsp=13
# datetime:
# 2020-08-29
# Semi Remolque
# precio:7900000
# Otros vehículos
# 2014-05-01
# https://www.yapo.cl/region_metropolitana
01
# https://www.yapo.cl/region_metropolitana/accesorios_vehiculos/pedal_de_acelerador_para_kia_k_2_4_bnn_74038411.htm?ca=15_s&oa=74038411&xsp=27
# datetime:
# 2020-08-29
# Pedal de acelerador para kia k 2.4 bnn
# precio:20000
# Accesorios y piezas para vehículos
# 2020-08-01
# 1062 (23000): Duplicate entry 'DesarmaduriaSotoMayor2_Región_Conchalí' for key 'PRIMARY'
# https://www.yapo.cl/region_metropolitana/bicicletas_ciclismo/bicicleta_montana_74038410.htm?ca=15_s&oa=74038410&xsp=28
# datetime:
# 2020-08-29
# Bicicleta montaña
# precio:35000
# Bicicletas, ciclismo y accesorios
# 2014-10-01
# https://www.yapo.cl/maule/autos/kia_sportage__diesel_4wd_74038409.htm?ca=8_s&oa=74038409&xsp=29
# datetime:
# 2020-08-29
# Kia Sportage, diesel 4WD
# precio:5500000
# Autos, camionetas y 4x4
# 2016-01-01
# https://www.yapo.cl/region_metropolitana/muebles/colchon_king_usado__74038408.htm?ca=15_s&oa=74038408&xsp=30
# datetime:
# 2020-08-29
# Colchon king usado
# precio:20000
# Muebles
# 2016-05-01
# https://www.yapo.cl/region_metropolitana/arte_antiguedades_colecciones/radio_antigua_admiral_ano_1953_74038407.htm?ca=15_s&oa=74038407&xsp=31
# datetime:
# 2020-08-29
# Radio Antigua Admiral Año 1953
# precio:250000
# Arte, antigüedades y colecciones
# 2014-12-01
# 1062 (23000): Duplicate entry 'Servitelcom Telecomunicaciones_Región_San Bernardo' for key 'PRIMARY'
# https://www.yapo.cl/antofagasta/consolas_videojuegos/juego_ps4_crash_bandicoot_trilogy_nuevo__sellado_74038406.htm?ca=3_s&oa=74038406&xsp=32
# datetime:
# 2020-08-29
# Juego ps4 Crash bandicoot Trilogy nuevo, sellado
# precio:20000
# Consolas, videojuegos y accesorios
# 2016-05-01
# 1062 (23000): Duplicate entry 'jona_return_II_Antofagasta' for key 'PRIMARY'
# https://www.yapo.cl/region_metropolitana/accesorios_vehiculos/envase_de_agua_para_kia_k_2_4_bnn_74038404.htm?ca=15_s&oa=74038404&xsp=33
# datetime:
# 2020-08-29
# Envase de agua para kia k 2.4 bnn
# precio:25000
# Accesorios y piezas para vehículos
# 2020-08-01
# 1062 (23000): Duplicate entry 'DesarmaduriaSotoMayor2_Región_Conchalí' for key 'PRIMARY'
# https://www.yapo.cl/magallanes_antartica/consolas_videojuegos/busco_juego_para_play_4_74038403.htm?ca=14_s&oa=74038403&xsp=34
# datetime:
# 2020-08-29
# Busco juego para play 4
# Consolas, videojuegos y accesorios
# 2015-08-01
# int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# https://www.yapo.cl/biobio/autos/jeep_misubichi_montero_74038402.htm?ca=9_s&oa=74038402&xsp=35
# datetime:
# 2020-08-29
# Jeep misubichi montero
# precio:12500000
# Autos, camionetas y 4x4
# 2014-07-01
# https://www.yapo.cl/valparaiso/jardin_herramientas/sillas_de_playa_tumbonas_74038401.htm?ca=6_s&oa=74038401&xsp=36
# datetime:
# 2020-08-29
# Sillas de playa Tumbonas
# precio:120000
# Jardín, herramientas y exteriores
# 2015-10-01
# https://www.yapo.cl/los_rios/consolas_videojuegos/busco_volante_para_play_2_74038400.htm?ca=11_s&oa=74038400&xsp=37
# datetime:
# 2020-08-29
# busco volante para play 2
# Consolas, videojuegos y accesorios
# 2015-09-01
# int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# https://www.yapo.cl
# datetime:
# 2020-08-29
# Botines Marquis Talla 38
# precio:6000
# Calzado
# 2013-11-01
# https://www.yapo.cl/biobio/moda-vestuario/chiporro_falcone_74038475.htm?ca=9_s&oa=74038475&xsp=4
# datetime:
# 2020-08-29
# Chiporro Falcone
# precio:15000
# Moda y vestuario
# 2020-08-01
# https://www.yapo.cl/region_metropolitana/calzado/calzado_de_seguridad_74038474.htm?ca=15_s&oa=74038474&xsp=5
# datetime:
# 2020-08-29
# Calzado de seguridad
# precio:15000
# Calzado
# 2020-07-01
# https://www.yapo.cl/region_metropolitana/negocios_maquinaria_construccion/plotter_hp_designjet_t_830_36__multifuncional_imp_74038473.htm?ca=15_s&oa=74038473&xsp=6
# datetime:
# 2020-08-29
# Plotter Hp Designjet T-830 36" Multifuncional Imp
# precio:2100000
# Negocios, maquinaria y construcción
# 2014-09-01
# https://www.yapo.cl/region_metropolitana/electrodomesticos/salamandra_directa___esqueleto_playera_descanso_74038472.htm?ca=15_s&oa=74038472&xsp=7
# datetime:
# 2020-08-29
# Salamandra directa + esqueleto playera descanso
# precio:50000
# Electrodomésticos
# 2020-05-01
# 1062 (23000): Duplicate entry 'José_Región_Paine' for key 'PRIMARY'
# https://www.yapo.cl/valparaiso/autos/por_renovacion_74038471.htm?ca=6_s&oa=74038471&xsp=8
# datetime:
# 2020-08-29
# por renovación
# precio:3600000
# Autos, camionetas y 4x4
# 2018-08-01
# https://www.yapo.cl/region_metropolitana/celulares/iphone_8_64gb__74038470.htm?ca=15_s&oa=74038470&xsp=9
# datetime:
# 2020-08-29
# Iphone 8 64gb
# precio:250000
# Celulares, teléfonos y accesorios
# 2020-08-01
# https://www.yapo.cl/coquimbo/autos/mitsubishi_l200_74038469.htm?ca=5_s&oa=74038469&xsp=10
# datetime:
# 2020-08-29
# Mitsubishi L200
# ...
# datetime:
# 2020-08-29
# Bolso grande con ruedas
# precio:35000
# Bolsos, bisutería y accesorios
# 2013-12-01
# https://www.yapo.cl/region_metropolitana/autos/grand_cherokee_2001_74038539.htm?ca=15_s&oa=74038539&xsp=31
# datetime:
# 2020-08-29
# Grand Cherokee 2001
# precio:4600000
# Autos, camionetas y 4x4
# 2014-05-01
# https://www.yapo.cl/region_metropolitana/salud-belleza/muletas_perfecto_estado_74038538.htm?ca=15_s&oa=74038538&xsp=32
# datetime:
# 2020-08-29
# Muletas perfecto estado
# precio:15000
# Salud y belleza
# 2015-03-01
# https://www.yapo.cl/antofagasta/autos/great_wall_h3_ano_2013_74038537.htm?ca=3_s&oa=74038537&xsp=33
# datetime:
# 2020-08-29
# Great Wall H3 año 2013
# precio:5600000
# Autos, camionetas y 4x4
# 2018-04-01
# https://www.yapo.cl/valparaiso/celulares/transmisor_icom_718_74038536.htm?ca=6_s&oa=74038536&xsp=34
# datetime:
# 2020-08-29
# Transmisor icom 718
# precio:650000
# Celulares, teléfonos y accesorios
# 2013-12-01
# https://www.yapo.cl/magallanes_antartica/calzado/zapatillas_adidas_skateboarding_74038535.htm?ca=14_s&oa=74038535&xsp=35
# datetime:
# 2020-08-29
# Zapatillas Adidas Skateboarding
# precio:25000
# Calzado
# 2019-06-01
# https://www.yapo.cl/ohiggins/moda-vestuario/vestido_urb_talla_l_74038534.htm?ca=7_s&oa=74038534&xsp=36
# datetime:
# 2020-08-29
# Vestido urb talla L
# precio:5000
# Moda y vestuario
# 2017-01-01
# https://www.yapo.cl/region_metropolitana/muebles/sillon_rojo_74038533.htm?ca=15_s&oa=74038533&xsp=37
# datetime:
# 2020-08-29
# Sillón rojo
# precio:180000
# Muebles
# 2019-03-01
# 1062 (23000): Duplicate entry 'bettina_Región_Colina' for key 'PRIMARY'
# https://www.yapo.cl/region_metropolitana/deportes_gimnasia/tobillera_y_munequera_74038532.htm?ca=15_s&oa=74038532&xsp=38
# datetime:
# 2020-08-29
# Tobillera y muñequera
# precio:13000
# Deportes, gimnasia y accesorios
# 2016-03-01
# https://www.yapo.cl/region_metropolitana/muebles/bergere_74038531.htm?ca=15_s&oa=74038531&xsp=39
# datetime:
# 2020-08-29
# Bergere
# precio:60000
# Muebles
# 2017-01-01
# https://www.yapo.cl/region_metropolitana/accesorios_vehiculos/servo_de_freno_para_kia_k_2_4_97_bnn_74038530.htm?ca=15_s&oa=74038530&xsp=40
# datetime:
# 2020-08-29
# Servo de freno para kia k 2.4 97 bnn
# precio:35000
# Accesorios y piezas para vehículos
# 2020-08-01
# 1062 (23000): Duplicate entry 'DesarmaduriaSotoMayor2_Región_Conchalí' for key 'PRIMARY'
# https://www.yapo.cl/region_metropolitana/accesorios_vehiculos/tapa_de_bencina_exterior_para_nissan_sentra_bnn_74038529.htm?ca=15_s&oa=74038529&xsp=41
# datetime:
# 2020-08-29
# Tapa de bencina exterior para Nissan sentra bnn
# precio:15000
# Accesorios y piezas para vehículos
# 2020-08-01
# 1062 (23000): Duplicate entry 'DesarmaduriaSotoMayor2_Región_Conchalí' for key 'PRIMARY'
# https://www.yapo.cl/los_lagos/arrendar/pers_sola_74038528.htm?ca=12_s&oa=74038528&xsp=42
# datetime:
# 2020-08-29
# pers sola
# precio:150000
# Arriendo - Casa
# 2014-11-01
# 1062 (23000): Duplicate entry 'carlos_X_Puerto Montt' for key 'PRIMARY'
# https://www.yapo.cl/biobio/juguetes/oso_gigante_74038527.htm?ca=9_s&oa=74038527&xsp=43
# datetime:
# 2020-08-29
# Oso gigante
# precio:35000
# Juguetes
# 2018-07-01
# 1062 (23000): Duplicate entry 'constanza martinez_VIII_Coronel' for key 'PRIMARY'
# https://www.yapo.cl/magallanes_antartica/autos/hyundai_accent_74038526.htm?ca=14_s&oa=74038526&xsp=44
# datetime:
# 2020-08-29
# Hyundai accent
# precio:4900000
# Autos, camionetas y 4x4
# 2015-09-01
# 1062 (23000): Duplicate entry 'pame_XII_Punta Arenas' for key 'PRIMARY'
# https://www.yapo.cl/region_metropolitana/accesorios_vehiculos/tapa_de_bencina_nissan_v16_twincan_ano_2000_bnn_74038525.htm?ca=15_s&oa=74038525&xsp=45
# datetime:
# 2020-08-29
# Tapa de bencina Nissan v16 twincan año 2000 bnn
# precio:15000
# Accesorios y piezas para vehículos
# 2020-08-01
# 1062 (23000): Duplicate entry 'DesarmaduriaSotoMayor2_Región_Conchalí' for key 'PRIMARY'
# https://www.yapo.cl/maule/autos/subaru_legacy__74038524.htm?ca=8_s&oa=74038524&xsp=46
# datetime:
# 2020-08-29
# Subaru legacy
# precio:850000
# Autos, camionetas y 4x4
# https://www.yapo.cl/region_metropolitana/accesorios_vehiculos/llantas_para_chevrolet_combo_1_4_bnn_74038523.htm?ca=15_s&oa=74038523&xsp=47
# datetime:
# 2020-08-29
# Llantas para Chevrolet combo 1.4 bnn
# precio:60000
# Accesorios y piezas para vehículos
# 2020-08-01
# 1062 (23000): Duplicate entry 'DesarmaduriaSotoMayor2_Región_Conchalí' for key 'PRIMARY'
# https://www.yapo.cl/region_metropolitana/accesorios_vehiculos/bomba_de_agua_nissan_v16_twincan_2000_bnn_74038522.htm?ca=15_s&oa=74038522&xsp=48
# datetime:
# 2020-08-29
# Bomba de agua Nissan v16 twincan 2000 bnn
# precio:20000
# Accesorios y piezas para vehículos
# 2020-08-01
# 1062 (23000): Duplicate entry 'DesarmaduriaSotoMayor2_Región_Conchalí' for key 'PRIMARY'
# https://www.yapo.cl/region_metropolitana/moda-vestuario/panuelo_azul_74038520.htm?ca=15_s&oa=74038520&xsp=49
# datetime:
# 2020-08-29
# Pañuelo azul
# precio:4000
# Moda y vestuario
# 2014-01-01
# 1062 (23000): Duplicate entry 'Constanza Vega_Región_Las Condes' for key 'PRIMARY'
# https://www.yapo.cl/region_metropolitana/calzado/zapatos_mujer_35___36_74038519.htm?ca=15_s&oa=74038519&xsp=0
# datetime:
# 2020-08-29
# zapatos mujer 35 - 36
# Calzado
# 2018-09-01
# 1062 (23000): Duplicate entry 'Rosa Bascuñan_Región_La Reina' for key 'PRIMARY'
# int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# https://www.yapo.cl/coquimbo/coches-articulos-infantiles/silla_de_bebe_74038518.htm?ca=5_s&oa=74038518&xsp=1
# datetime:
# 2020-08-29
# Silla de bebé
# precio:23000
# Coches y artículos infantiles
# 2017-09-01
# 1062 (23000): Duplicate entry 'pizarrovladimir7_IV_Coquimbo' for key 'PRIMARY'
# https://www.yapo.cl/region_metropolitana/ofertas_de_empleo/maestro_electrico_con_sec_santiago_74038517.htm?ca=15_s&oa=74038517&xsp=2
# datetime:
# 2020-08-29
# Maestro Eléctrico con SEC Santiago
# Ofertas de empleo
# 2019-02-01
# 1062 (23000): Duplicate entry 'INGENIERIA Z y F_Región_Huechuraba' for key 'PRIMARY'
# int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# https://www.yapo.cl/region_metropolitana/ofertas_de_empleo/ejecutivao_comercial_cortinas_hunter_74038516.htm?ca=15_s&oa=74038516&xsp=3
# datetime:
# 2020-08-29
# Ejecutivao comercial cortinas hunter
# precio:700000
# Ofertas de empleo
# 2020-07-01
# 1062 (23000): Duplicate entry 'go work_Región_Las Condes' for key 'PRIMARY'
# https://www.yapo.cl/aisen/ofertas_de_empleo/trabajo_74038515.htm?ca=13_s&oa=74038515&xsp=4
# datetime:
# 2020-08-29
# Trabajo
# Ofertas de empleo
# 2019-10-01
# 1062 (23000): Duplicate entry 'oscar.matias.araneda_XI_Coyhaique' for key 'PRIMARY'
# int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# https://www.yapo.cl/tarapaca/moda-vestuario/croptop_laceup_74038514.htm?ca=2_s&oa=74038514&xsp=5
# datetime:
# 2020-08-29
# Croptop laceup
# precio:5000
# Moda y vestuario
# 2016-07-01
# 1062 (23000): Duplicate entry 'Fernanda Aguirre_I_Iquique' for key 'PRIMARY'
# https://www.yapo.cl/coquimbo/motos/busco__moto_en_cuotas__74038513.htm?ca=5_s&oa=74038513&xsp=6
# datetime:
# 2020-08-29
# Busco: Moto en cuotas
# precio:4000000
# Motos
# 2014-07-01
# 1062 (23000): Duplicate entry 'Juan Vargas_IV_Coquimbo' for key 'PRIMARY'
# https://www.yapo.cl/region_metropolitana/libros_revistas/libros_novelas_varias_en_muy_buen_estado_74038512.htm?ca=15_s&oa=74038512&xsp=7
# datetime:
# 2020-08-29
# Libros novelas varias en muy buen estado
# precio:10000
# Libros y revistas
# 2015-07-01
# 1062 (23000): Duplicate entry 'Ma. José_Región_Vitacura' for key 'PRIMARY'
# https://www.yapo.cl/region_metropolitana/accesorios_vehiculos/motores_de_arranque_o_partida_74038511.htm?ca=15_s&oa=74038511&xsp=8
# datetime:
# 2020-08-29
# Motores de arranque o partida
# precio:123456789
# Accesorios y piezas para vehículos
# 2013-12-01
# 1062 (23000): Duplicate entry 'alex_Región_Estación Central' for key 'PRIMARY'
# https://www.yapo.cl/region_metropolitana/muebles/sillon_rojo_2_cuerpos__74038510.htm?ca=15_s&oa=74038510&xsp=9
# datetime:
# 2020-08-29
# Sillón rojo 2 cuerpos
# precio:80000
# Muebles
# 2014-07-01
# 1062 (23000): Duplicate entry 'Marcelo M._Región_Santiago' for key 'PRIMARY'
# https://www.yapo.cl/region_metropolitana/muebles/mesa_de_centro__74038509.htm?ca=15_s&oa=74038509&xsp=10
# datetime:
# 2020-08-29
# Mesa de centro
# precio:60000
# Muebles
# 2015-09-01
# 1062 (23000): Duplicate entry 'valentina _Región_Ñuñoa' for key 'PRIMARY'
# https://www.yapo.cl/region_metropolitana/instrumentos_musicales/piano_kawai_cn_24_en_perfectas_condiciones_74038508.htm?ca=15_s&oa=74038508&xsp=11
# datetime:
# 2020-08-29
# Piano Kawai Cn 24 en perfectas condiciones
# precio:990000
# Instrumentos musicales y accesorios
# 2020-07-01
# 1062 (23000): Duplicate entry 'PAMELA ALEJANDRA MALEBRAN GUERRERO_Región_Las Condes' for key 'PRIMARY'
# https://www.yapo.cl/araucania/autos/toyota_yaris_2003_73958710.htm?ca=10_s&oa=73958710&xsp=12
# datetime:
# 2020-08-29
# Toyota yaris 2003
# precio:3100000
# Autos, camionetas y 4x4
# 2017-02-01
# 1062 (23000): Duplicate entry 'Jose Bello Baeza_IX_Temuco' for key 'PRIMARY'
# https://www.yapo.cl/region_metropolitana/comprar/departamento_ubicado_en_hermoso_condominio_73913188.htm?ca=15_s&oa=73913188&xsp=13
# datetime:
# 2020-08-29
# Departamento ubicado en hermoso condominio
# precio:2700
# Vendo - Departamento
# 2020-08-01
# 1062 (23000): Duplicate entry 'Mario Soto C_Región_San Joaquín' for key 'PRIMARY'
# https://www.yapo.cl/nuble/musica_peliculas/vinilo_agnetha_f_ltskog__abba____eyes_of_a_woman_74038507.htm?ca=16_s&oa=74038507&xsp=14
# datetime:
# 2020-08-29
# Vinilo Agnetha Fältskog (ABBA) - Eyes Of A Woman
# precio:18000
# Música y películas (DVDs, etc.)
# 2016-08-01
# 1062 (23000): Duplicate entry 'Esteban_XVI_Chillán' for key 'PRIMARY'
# https://www.yapo.cl/coquimbo/computadores/notebook_hp_en_perfectas_condiciones_74038506.htm?ca=5_s&oa=74038506&xsp=15
# datetime:
# 2020-08-29
# Notebook Hp en perfectas condiciones
# precio:250000
# Computadores y accesorios
# 2014-02-01
# 1062 (23000): Duplicate entry 'Francisca_IV_Coquimbo' for key 'PRIMARY'
# https://www.yapo.cl/region_metropolitana/autos/suzuki_alto_k10_2018_74038505.htm?ca=15_s&oa=74038505&xsp=16
# datetime:
# 2020-08-29
# Suzuki alto k10 2018
# precio:3900000
# Autos, camionetas y 4x4
# 2014-05-01
# 1062 (23000): Duplicate entry 'Karina Zumaeta_Región_Pudahuel' for key 'PRIMARY'
# https://www.yapo.cl/region_metropolitana/celulares/apple_watch_74038504.htm?ca=15_s&oa=74038504&xsp=17
# datetime:
# 2020-08-29
# Apple watch
# precio:120000
# Celulares, teléfonos y accesorios
# 2015-07-01
# 1062 (23000): Duplicate entry 'benjamincuitinovescovi_Región_Peñalolén' for key 'PRIMARY'
# https://www.yapo.cl/region_metropolitana/autos/mitsubishi_montero_2_5_2007_74038503.htm?ca=15_s&oa=74038503&xsp=18
# datetime:
# 2020-08-29
# Mitsubishi Montero 2.5 2007
# precio:6780000
# Autos, camionetas y 4x4
# 2019-07-01
# 1062 (23000): Duplicate entry 'CQuero Automotriz_Región_La Florida' for key 'PRIMARY'
# https://www.yapo.cl/region_metropolitana/coches-articulos-infantiles/corral_plastico_bebe_74038502.htm?ca=15_s&oa=74038502&xsp=19
# datetime:
# 2020-08-29
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-e940249ab043> in <module>
#      38
#      39         #RECUPERAMOS EL TITULO DEL ANUNCIO
# ---> 40         pageSoup = soup(browser.page_source, 'html.parser')
#      41         if(pageSoup.find('h1', {"id" : "da_subject"})):
#      42             titulo = pageSoup.find('h1', {"id" : "da_subject"}).text.strip()
#
# ~/miniconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in page_source(self)
#     677             driver.page_source
#     678         """
# --> 679         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     680
#     681     def close(self):
#
# ~/miniconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~/miniconda3/lib/python3.8/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~/miniconda3/lib/python3.8/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~/miniconda3/lib/python3.8/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      73
#      74         if method in self._encode_url_methods:
# ---> 75             return self.request_encode_url(
#      76                 method, url, fields=fields, headers=headers, **urlopen_kw
#      77             )
#
# ~/miniconda3/lib/python3.8/site-packages/urllib3/request.py in request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      95             url += "?" + urlencode(fields)
#      96
# ---> 97         return self.urlopen(method, url, **extra_kw)
#      98
#      99     def request_encode_body(
#
# ~/miniconda3/lib/python3.8/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     328             response = conn.urlopen(method, url, **kw)
#     329         else:
# --> 330             response = conn.urlopen(method, u.request_uri, **kw)
#     331
#     332         redirect_location = redirect and response.get_redirect_location()
#
# ~/miniconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     663
#     664             # Make the request on the httplib connection object.
# --> 665             httplib_response = self._make_request(
#     666                 conn,
#     667                 method,
#
# ~/miniconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/miniconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/miniconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# ~/miniconda3/lib/python3.8/http/client.py in getresponse(self)
#    1330         try:
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#    1334                 self.close()
#
# ~/miniconda3/lib/python3.8/http/client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# ~/miniconda3/lib/python3.8/http/client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# ~/miniconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
import numpy as np
import pandas as pd
import shapefile as shp
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from pandas import DataFrame
import pandas as pd

sns.set(style="whitegrid", palette="pastel", color_codes=True)
sns.mpl.rc("figure", figsize=(12,6))

# %%
cursor.execute("USE Yapo2")
sql = "SELECT categoria, avg(precio) FROM anuncio WHERE moneda=\"$\" GROUP BY categoria ORDER BY avg(precio) DESC;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1
# Out:
#                                  categoria     avg(precio)
# 0                     Vendo - Departamento  399999000.0000
# 1                             Vendo - Casa   21500000.0000
# 2               Buses, camiones y furgones   12222857.1429
# 3       Accesorios y piezas para vehículos    9212539.9259
# 4                          Vendo - Terreno    8490000.0000
# 5                          Otros vehículos    7900000.0000
# 6                Barcos, lanchas y aviones    7000000.0000
# 7                  Autos, camionetas y 4x4    6823294.1176
# 8                                    Motos    3166666.6667
# 9         Arte, antigüedades y colecciones    2562500.0000
# 10     Negocios, maquinaria y construcción    2100000.0000
# 11  Vendo - Estacionamiento, bodega u otro    2000000.0000
# 12     Instrumentos musicales y accesorios     990000.0000
# 13               Animales y sus accesorios     720000.0000
# 14                       Ofertas de empleo     470000.0000
# 15                         Arriendo - Casa     391111.1111
# 16                 Arriendo - Departamento     345185.1852
# 17           Audio, TV, video y fotografía     286666.6667
# 18       Celulares, teléfonos y accesorios     135213.5714
# 19                                 Muebles     125132.8846
# 20       Bicicletas, ciclismo y accesorios     116428.5714
# 21               Computadores y accesorios     116000.0000
# 22                        Arriendo - Pieza     110000.0000
# 23       Jardín, herramientas y exteriores     104875.0000
# 24                               Servicios      82180.0000
# 25      Consolas, videojuegos y accesorios      66250.0000
# 26                       Electrodomésticos      66000.0000
# 27         Deportes, gimnasia y accesorios      63250.0000
# 28                         Salud y belleza      36997.1429
# 29                                 Calzado      36923.0769
# 30           Coches y artículos infantiles      25333.3333
# 31                                Juguetes      20833.3333
# 32         Música y películas (DVDs, etc.)      20333.3333
# 33           Vestuario futura mamá y niños      20000.0000
# 34                        Moda y vestuario      18681.3636
# 35               Otros artículos del hogar      15610.0000
# 36          Bolsos, bisutería y accesorios      13058.7500
# 37                       Libros y revistas       8000.0000

# %%
sql = "select DAYOFWEEK(fecha_publicacion) as dia,categoria, avg(precio) from anuncio where moneda=\"$\" group by dia, categoria order by avg(precio) desc;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names

df1sql = "SELECT categoria, avg(precio) FROM anuncio WHERE moneda=\"$\" GROUP BY categoria ORDER BY avg(precio) DESC;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1
# Out:
#     dia                               categoria     avg(precio)
# 0     7                    Vendo - Departamento  399999000.0000
# 1     7                            Vendo - Casa   21500000.0000
# 2     7              Buses, camiones y furgones   12222857.1429
# 3     7      Accesorios y piezas para vehículos    9212539.9259
# 4     7                         Vendo - Terreno    8490000.0000
# 5     7                         Otros vehículos    7900000.0000
# 6     7               Barcos, lanchas y aviones    7000000.0000
# 7     7                 Autos, camionetas y 4x4    6823294.1176
# 8     7                                   Motos    3166666.6667
# 9     7        Arte, antigüedades y colecciones    2562500.0000
# 10    7     Negocios, maquinaria y construcción    2100000.0000
# 11    7  Vendo - Estacionamiento, bodega u otro    2000000.0000
# 12    7     Instrumentos musicales y accesorios     990000.0000
# 13    7               Animales y sus accesorios     720000.0000
# 14    7                       Ofertas de empleo     470000.0000
# 15    7                         Arriendo - Casa     391111.1111
# 16    7                 Arriendo - Departamento     345185.1852
# 17    7           Audio, TV, video y fotografía     286666.6667
# 18    7       Celulares, teléfonos y accesorios     135213.5714
# 19    7                                 Muebles     125132.8846
# 20    7       Bicicletas, ciclismo y accesorios     116428.5714
# 21    7               Computadores y accesorios     116000.0000
# 22    7                        Arriendo - Pieza     110000.0000
# 23    7       Jardín, herramientas y exteriores     104875.0000
# 24    7                               Servicios      82180.0000
# 25    7      Consolas, videojuegos y accesorios      66250.0000
# 26    7                       Electrodomésticos      66000.0000
# 27    7         Deportes, gimnasia y accesorios      63250.0000
# 28    7                         Salud y belleza      36997.1429
# 29    7                                 Calzado      36923.0769
# 30    7           Coches y artículos infantiles      25333.3333
# 31    7                                Juguetes      20833.3333
# 32    7         Música y películas (DVDs, etc.)      20333.3333
# 33    7           Vestuario futura mamá y niños      20000.0000
# 34    7                        Moda y vestuario      18681.3636
# 35    7               Otros artículos del hogar      15610.0000
# 36    7          Bolsos, bisutería y accesorios      13058.7500
# 37    7                       Libros y revistas       8000.0000

# %%
sql = "ALTER TABLE vendedor ADD perfil VARCHAR(10);"
cursor.execute(sql)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~/miniconda3/lib/python3.8/site-packages/mysql/connector/connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     486                 query = query.encode('utf-8')
# --> 487             self._cmysql.query(query,
#     488                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Duplicate column name 'perfil'
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-5-95c0e194a0dd> in <module>
#       1 sql = "ALTER TABLE vendedor ADD perfil VARCHAR(10);"
# ----> 2 cursor.execute(sql)
#
# ~/miniconda3/lib/python3.8/site-packages/mysql/connector/cursor_cext.py in execute(self, operation, params, multi)
#     262
#     263         try:
# --> 264             result = self._cnx.cmd_query(stmt, raw=self._raw,
#     265                                          buffered=self._buffered,
#     266                                          raw_as_string=self._raw_as_string)
#
# ~/miniconda3/lib/python3.8/site-packages/mysql/connector/connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     489                                raw_as_string=raw_as_string)
#     490         except MySQLInterfaceError as exc:
# --> 491             raise errors.get_mysql_exception(exc.errno, msg=exc.msg,
#     492                                              sqlstate=exc.sqlstate)
#     493         except AttributeError:
#
# ProgrammingError: 1060 (42S21): Duplicate column name 'perfil'

# %%
sql = "UPDATE vendedor SET perfil=\"Personal\";"
cursor.execute(sql)
cursor.execute("COMMIT")

# %%
sql = "SELECT id_vendedor FROM anuncio JOIN vendedor USING (id_vendedor)  GROUP BY id_vendedor HAVING count(*) >= 5 ORDER BY count(*) DESC;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
#print(df1[:5])

for index,row in df1.iterrows():
    id_vendedor=row[0]
    
    sql = "UPDATE vendedor SET perfil=\"Pro\" WHERE id_vendedor=\""+id_vendedor+"\";"
    cursor.execute(sql)

cursor.execute("COMMIT")

# %%
sql = "SELECT perfil, count(*) as vendedores FROM vendedor GROUP BY perfil;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1
# Out:
#      perfil  vendedores
# 0  Personal         223
# 1       Pro           5

# %%
shp_path = "./cl_regiones_geo/cl_regiones_geo.shp"
sf = shp.Reader(shp_path, encoding="ISO8859-1")

# %%
len(sf.shapes())
# Out:
# 15

# %%
sf.records()[2]
# Out:
# Record #2: ['02', 'Antofagasta']

# %%
sf.records()[1][1]
# Out:
# 'Tarapaca'

# %%
def read_shapefile(sf):
    """
    Read a shapefile into a Pandas dataframe with a 'coords' 
    column holding the geometry information. This uses the pyshp
    package
    """
    fields = [x[0] for x in sf.fields][1:]
    records = sf.records()
    shps = [s.points for s in sf.shapes()]
    df = pd.DataFrame(columns=fields, data=records)
    df = df.assign(coords=shps)
    return df

# %%
df = read_shapefile(sf)
df.shape
# Out:
# (15, 3)

# %%
df.sample(15)
# Out:
#    ID_2002                                   NOMBRE  \
# 6       13                Metropolitana de Santiago
# 10      09                             La Araucania
# 0       15                       Arica y Parinacota
# 11      14                                 Los Rios
# 3       03                                  Atacama
# 1       01                                 Tarapaca
# 2       02                              Antofagasta
# 14      12     Magallanes y de la Antartica Chileno
# 7       06      Libertador Gral. Bernardo O'Higgins
# 8       07                                    Maule
# 9       08                                   Biobio
# 12      10                                Los Lagos
# 5       05                               Valparaiso
# 4       04                                 Coquimbo
# 13      11  Aisen del Gral. Carlos Ibañez del Campo
#
#                                                coords
# 6   [(-70.24362, -33.187388), (-70.242295, -33.184...
# 10  [(-71.044287, -38.123172), (-71.029341, -38.13...
# 0   [(-70.266233, -19.190222), (-70.27196, -19.188...
# 11  [(-71.967833, -40.63312), (-71.971205, -40.634...
# 3   [(-68.544889, -25.298825), (-68.543865, -25.31...
# 1   [(-70.286169, -19.228974), (-70.130959, -19.15...
# 2   [(-68.481222, -20.945989), (-68.480813, -20.94...
# 14  [(-74.704448, -50.202635), (-74.704448, -50.20...
# 7   [(-70.03126, -34.28848), (-70.031713, -34.2923...
# 8   [(-70.363785, -35.003876), (-70.364762, -35.00...
# 9   [(-73.684488, -37.367238), (-73.684134, -37.36...
# 12  [(-73.720279, -40.247128), (-73.718843, -40.24...
# 5   [(-70.319802, -32.274733), (-70.314426, -32.27...
# 4   [(-69.952308, -29.503367), (-69.951567, -29.50...
# 13  [(-72.737018, -43.829555), (-72.738551, -43.82...

# %%
df[df.NOMBRE == 'Los Rios']
# Out:
#    ID_2002    NOMBRE                                             coords
# 11      14  Los Rios  [(-71.967833, -40.63312), (-71.971205, -40.634...

# %%
def calc_color(data, color=None):
        if color   == 1: 
            color_sq =  ['#dadaebFF','#bcbddcF0','#9e9ac8F0',
                        '#807dbaF0','#6a51a3F0','#54278fF0']; 
            colors = 'Purples';
        elif color == 2: 
            color_sq = ['#c7e9b4','#7fcdbb','#41b6c4',
                        '#1d91c0','#225ea8','#253494']; 
            colors = 'YlGnBu';
        elif color == 3: 
            color_sq = ['#f7f7f7','#d9d9d9','#bdbdbd',
                        '#969696','#636363','#252525']; 
            colors = 'Greys';
        elif color == 9: 
            color_sq = ['#ff0000','#ff0000','#ff0000',
                        '#ff0000','#ff0000','#ff0000']
        else:            
            color_sq = ['#ffffd4','#fee391','#fec44f',
                        '#fe9929','#d95f0e','#993404']; 
            colors = 'YlOrBr';
        
        new_data, bins = pd.qcut(data, 6, retbins=True, labels=list(range(6)))
        color_ton = []
        for val in new_data:
            color_ton.append(color_sq[val]) 
        if color != 9:
            colors = sns.color_palette(colors, n_colors=6)
            sns.palplot(colors, 0.6);
            for i in range(6):
                print ("\n"+str(i+1)+': '+str(int(bins[i]))+
                       " => "+str(int(bins[i+1])-1), end =" ")
            print("\n\n   1   2   3   4   5   6")    
        return color_ton, bins;

# %%
def plot_regiones_data(sf, title, regiones, data=None, 
                      color=None, print_id=False):
    '''
    Plot map with selected comunes, using specific color
    '''
    
    color_ton, bins = calc_color(data, color)
    df = read_shapefile(sf)
    region_id = []
    for i in regiones:
        #print(i)
        id = df[df.NOMBRE == i].index.get_values()[0]
        region_id.append(id)
        
        
    y_lim = (-41,-17) # latitude 
    x_lim = (-76, -66) # longitude
    
    plot_map_fill_multiples_ids_tone(sf, title, region_id, 
                                     print_id, 
                                     color_ton, 
                                     bins, 
                                     x_lim = x_lim, 
                                     y_lim = y_lim, 
                                     figsize = (10,25));

# %%
def plot_map_fill_multiples_ids_tone(sf, title, comuna,  
                                     print_id, color_ton, 
                                     bins, 
                                     x_lim = None, 
                                     y_lim = None, 
                                     figsize = (5,12)):
    '''
    Plot map with lim coordinates
    '''
        
    plt.figure(figsize = figsize)
    fig, ax = plt.subplots(figsize = figsize)
    fig.suptitle(title, fontsize=16)
    for shape in sf.shapeRecords():
        x = [i[0] for i in shape.shape.points[:]]
        y = [i[1] for i in shape.shape.points[:]]
        ax.plot(x, y, 'k')
            
    for id in comuna:
        shape_ex = sf.shape(id)
        x_lon = np.zeros((len(shape_ex.points),1))
        y_lat = np.zeros((len(shape_ex.points),1))
        for ip in range(len(shape_ex.points)):
            x_lon[ip] = shape_ex.points[ip][0]
            y_lat[ip] = shape_ex.points[ip][1]
        ax.fill(x_lon,y_lat, color_ton[comuna.index(id)])
        if print_id != False:
            x0 = np.mean(x_lon)
            y0 = np.mean(y_lat)
            plt.text(x0, y0, id, fontsize=10)
    if (x_lim != None) & (y_lim != None):     
        plt.xlim(x_lim)
        plt.ylim(y_lim)

# %%
from pandas import DataFrame
#¿Cuál es el número de anuncios Yapo.cl en cada región de Chile ?

sql = "select nombre_region, count(*) as nb_anuncios from vendedor join anuncio using (id_vendedor) where nombre_region != \"Ñuble\" group by nombre_region order by nb_anuncios DESC;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1
# Out:
#              nombre_region  nb_anuncios
# 0            Metropolitana          177
# 1                   Biobío           18
# 2                    Maule           14
# 3               Valparaíso           14
# 4                Araucanía           13
# 5                 Coquimbo           12
# 6                Los Lagos           11
# 7   Magallanes & Antártica           11
# 8                 Tarapacá           10
# 9                O'Higgins            9
# 10             Antofagasta            8
# 11      Arica & Parinacota            5
# 12                 Atacama            5
# 13                Los Ríos            2
# 14                   Aisén            1

# %%
read_shapefile(sf).head(15)
# Out:
#    ID_2002                                   NOMBRE  \
# 0       15                       Arica y Parinacota
# 1       01                                 Tarapaca
# 2       02                              Antofagasta
# 3       03                                  Atacama
# 4       04                                 Coquimbo
# 5       05                               Valparaiso
# 6       13                Metropolitana de Santiago
# 7       06      Libertador Gral. Bernardo O'Higgins
# 8       07                                    Maule
# 9       08                                   Biobio
# 10      09                             La Araucania
# 11      14                                 Los Rios
# 12      10                                Los Lagos
# 13      11  Aisen del Gral. Carlos Ibañez del Campo
# 14      12     Magallanes y de la Antartica Chileno
#
#                                                coords
# 0   [(-70.266233, -19.190222), (-70.27196, -19.188...
# 1   [(-70.286169, -19.228974), (-70.130959, -19.15...
# 2   [(-68.481222, -20.945989), (-68.480813, -20.94...
# 3   [(-68.544889, -25.298825), (-68.543865, -25.31...
# 4   [(-69.952308, -29.503367), (-69.951567, -29.50...
# 5   [(-70.319802, -32.274733), (-70.314426, -32.27...
# 6   [(-70.24362, -33.187388), (-70.242295, -33.184...
# 7   [(-70.03126, -34.28848), (-70.031713, -34.2923...
# 8   [(-70.363785, -35.003876), (-70.364762, -35.00...
# 9   [(-73.684488, -37.367238), (-73.684134, -37.36...
# 10  [(-71.044287, -38.123172), (-71.029341, -38.13...
# 11  [(-71.967833, -40.63312), (-71.971205, -40.634...
# 12  [(-73.720279, -40.247128), (-73.718843, -40.24...
# 13  [(-72.737018, -43.829555), (-72.738551, -43.82...
# 14  [(-74.704448, -50.202635), (-74.704448, -50.20...

# %%
df1.loc[df1.nombre_region == "Metropolitana", "nombre_region"] = "Metropolitana de Santiago"
df1.loc[df1.nombre_region == "Valparaíso", "nombre_region"] = "Valparaiso"
df1.loc[df1.nombre_region == "Biobío", "nombre_region"] = "Biobio"
df1.loc[df1.nombre_region == "Magallanes & Antártica", "nombre_region"] = "Magallanes y de la Antartica Chileno"
df1.loc[df1.nombre_region == "Araucanía", "nombre_region"] = "La Araucania"
df1.loc[df1.nombre_region == "O'Higgins", "nombre_region"] = "Libertador Gral. Bernardo O'Higgins"
df1.loc[df1.nombre_region == "Los Ríos", "nombre_region"] = "Los Rios"
df1.loc[df1.nombre_region == "Tarapacá", "nombre_region"] = "Tarapaca"
df1.loc[df1.nombre_region == "Aisén", "nombre_region"] = "Aisen del Gral. Carlos Ibañez del Campo"
df1.loc[df1.nombre_region == "Arica & Parinacota", "nombre_region"] = "Arica y Parinacota"

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
data = df1.nb_anuncios
regiones = df1.nombre_region

print_id = False # The shape id will be printed
color_pallete = 1 # 'Purples'
plot_regiones_data(sf, 'Número de anuncios Yapo.cl por regiones', regiones, data, color_pallete, print_id)
# Out:
# 1: 1 => 4
# 2: 5 => 7
# 3: 8 => 10
# 4: 11 => 11
# 5: 12 => 13
# 6: 14 => 176
#
#    1   2   3   4   5   6
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-f2cab76da2dc> in <module>
#       4 print_id = False # The shape id will be printed
#       5 color_pallete = 1 # 'Purples'
# ----> 6 plot_regiones_data(sf, 'Número de anuncios Yapo.cl por regiones', regiones, data, color_pallete, print_id)
#
# <ipython-input-18-4967b5d9a310> in plot_regiones_data(sf, title, regiones, data, color, print_id)
#      10     for i in regiones:
#      11         #print(i)
# ---> 12         id = df[df.NOMBRE == i].index.get_values()[0]
#      13         region_id.append(id)
#      14
#
# AttributeError: 'Int64Index' object has no attribute 'get_values'

# %%
pd.options.display.max_colwidth = 300

sql = "select url,titulo,precio from anuncio where moneda = \"$\" and categoria = \"Arriendo - Departamento\" order by precio DESC;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1[:20]
# Out:
#                                                                                                                                           url  \
# 0                         https://www.yapo.cl/antofagasta/arrendar/necesito_departamento_2_dormitorios_74038461.htm?ca=3_s&oa=74038461&xsp=18
# 1          https://www.yapo.cl/region_metropolitana/arrendar/depto_1_dormitorio_frente_parque_araucano_73952415.htm?ca=15_s&oa=73952415&xsp=4
# 2         https://www.yapo.cl/region_metropolitana/arrendar/depto_1_dormitorio_frente_parque_araucano_73952415.htm?ca=15_s&oa=73952415&xsp=38
# 3                       https://www.yapo.cl/region_metropolitana/arrendar/departamento_amoblado_maipu_73460555.htm?ca=15_s&oa=73460555&xsp=18
# 4                       https://www.yapo.cl/region_metropolitana/arrendar/departamento_amoblado_maipu_73460555.htm?ca=15_s&oa=73460555&xsp=34
# 5   https://www.yapo.cl/region_metropolitana/arrendar/excelente__amoblado_3_hab_prox_metro_hospitales_73731685.htm?ca=15_s&oa=73731685&xsp=23
# 6            https://www.yapo.cl/region_metropolitana/arrendar/depto_2d_y_2b___bodeg_metro_sta_isabel_72571513.htm?ca=15_s&oa=72571513&xsp=36
# 7            https://www.yapo.cl/region_metropolitana/arrendar/depto_2d_y_2b___bodeg_metro_sta_isabel_72571513.htm?ca=15_s&oa=72571513&xsp=20
# 8    https://www.yapo.cl/region_metropolitana/arrendar/3d_y_1b_gc_incluidos__metro_lo_vial__san_miguel_71304626.htm?ca=15_s&oa=71304626&xsp=0
# 9   https://www.yapo.cl/region_metropolitana/arrendar/3d_y_1b_gc_incluidos__metro_lo_vial__san_miguel_71304626.htm?ca=15_s&oa=71304626&xsp=34
# 10                     https://www.yapo.cl/region_metropolitana/arrendar/depto_3d_y_1b_independencia__73030565.htm?ca=15_s&oa=73030565&xsp=35
# 11                     https://www.yapo.cl/region_metropolitana/arrendar/depto_3d_y_1b_independencia__73030565.htm?ca=15_s&oa=73030565&xsp=19
# 12    https://www.yapo.cl/region_metropolitana/arrendar/arriendo_depto__garantia_y_comision_en_cuotas_73951885.htm?ca=15_s&oa=73951885&xsp=10
# 13    https://www.yapo.cl/region_metropolitana/arrendar/arriendo_depto__garantia_y_comision_en_cuotas_73951885.htm?ca=15_s&oa=73951885&xsp=26
# 14     https://www.yapo.cl/region_metropolitana/arrendar/departamento_sin_comision__garantia_en_cuotas_73952468.htm?ca=15_s&oa=73952468&xsp=9
# 15               https://www.yapo.cl/valparaiso/arrendar/departamento_exclusivo_sector_de_vina_del_mar_73077980.htm?ca=6_s&oa=73077980&xsp=31
# 16    https://www.yapo.cl/region_metropolitana/arrendar/departamento_sin_comision__garantia_en_cuotas_73952468.htm?ca=15_s&oa=73952468&xsp=25
# 17                                      https://www.yapo.cl/region_metropolitana/arrendar/departamento_73952692.htm?ca=15_s&oa=73952692&xsp=7
# 18                                     https://www.yapo.cl/region_metropolitana/arrendar/departamento_73952692.htm?ca=15_s&oa=73952692&xsp=23
# 19                        https://www.yapo.cl/araucania/arrendar/departamento_edificio_centro_lagos_2_72660022.htm?ca=10_s&oa=72660022&xsp=21
#
#                                              titulo  precio
# 0               Necesito departamento 2 dormitorios  500000
# 1         Depto.1 dormitorio frente Parque Araucano  450000
# 2         Depto.1 dormitorio frente Parque Araucano  450000
# 3                       Departamento amoblado Maipú  420000
# 4                       Departamento amoblado Maipú  420000
# 5   Excelente, amoblado,3 hab.prox metro hospitales  390000
# 6            Depto 2D y 2B + Bodeg Metro Sta Isabel  390000
# 7            Depto 2D y 2B + Bodeg Metro Sta Isabel  390000
# 8   3D y 1B GC Incluidos, Metro Lo Vial, San Miguel  360000
# 9   3D y 1B GC Incluidos, Metro Lo Vial, San Miguel  360000
# 10                      Depto 3D y 1B Independencia  350000
# 11                      Depto 3D y 1B Independencia  350000
# 12    Arriendo Depto, Garantía y Comisión en cuotas  340000
# 13    Arriendo Depto, Garantía y Comisión en cuotas  340000
# 14    Departamento Sin Comisión, Garantía en cuotas  330000
# 15    Departamento Exclusivo sector de Viña del Mar  330000
# 16    Departamento Sin Comisión, Garantía en cuotas  330000
# 17                                     Departamento  330000
# 18                                     Departamento  330000
# 19             Departamento Edificio Centro Lagos 2  320000

# %%
x = df1[9:]["precio"].to_numpy()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

sns.set(color_codes=True)

# %%
fig, ax = plt.subplots()
sns.distplot(x, kde=False, norm_hist=False)
ax.set_xlim(0,1400000)
# Out:
# (0.0, 1400000.0)

# %%
sql = "select nombre_region, avg(precio) as precio_prom from vendedor join anuncio using (id_vendedor) where categoria=\"Arriendo - Departamento\" and moneda=\"$\" and nombre_region != \"Ñuble\" and precio < 1500000 group by nombre_region order by precio_prom DESC;"
print(sql)
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1
# Out:
# select nombre_region, avg(precio) as precio_prom from vendedor join anuncio using (id_vendedor) where categoria="Arriendo - Departamento" and moneda="$" and nombre_region != "Ñuble" and precio < 1500000 group by nombre_region order by precio_prom DESC;
#    nombre_region  precio_prom
# 0    Antofagasta  500000.0000
# 1  Metropolitana  340416.6667
# 2     Valparaíso  330000.0000
# 3      Araucanía  320000.0000

# %%
df1["precio_prom"] = df1["precio_prom"].astype(int)
df1
# Out:
#    nombre_region  precio_prom
# 0    Antofagasta       500000
# 1  Metropolitana       340416
# 2     Valparaíso       330000
# 3      Araucanía       320000

# %%
df1.loc[df1.nombre_region == "Metropolitana", "nombre_region"] = "Metropolitana de Santiago"
df1.loc[df1.nombre_region == "Valparaíso", "nombre_region"] = "Valparaiso"
df1.loc[df1.nombre_region == "Biobío", "nombre_region"] = "Biobio"
df1.loc[df1.nombre_region == "Magallanes & Antártica", "nombre_region"] = "Magallanes y de la Antartica Chileno"
df1.loc[df1.nombre_region == "Araucanía", "nombre_region"] = "La Araucania"
df1.loc[df1.nombre_region == "O'Higgins", "nombre_region"] = "Libertador Gral. Bernardo O'Higgins"
df1.loc[df1.nombre_region == "Los Ríos", "nombre_region"] = "Los Rios"
df1.loc[df1.nombre_region == "Tarapacá", "nombre_region"] = "Tarapaca"
df1.loc[df1.nombre_region == "Aisén", "nombre_region"] = "Aisen del Gral. Carlos Ibañez del Campo"
df1.loc[df1.nombre_region == "Arica & Parinacota", "nombre_region"] = "Arica y Parinacota"

# %%
data = df1.precio_prom
regiones = df1.nombre_region

print_id = False # The shape id will be printed
color_pallete = 1 # 'Purples'
plot_regiones_data(sf, 'Valores de los arriendos de departamento por regiones (datos Yapo.cl)', regiones, data, color_pallete, print_id)
# Out:
# 1: 320000 => 324999
# 2: 325000 => 329999
# 3: 330000 => 335207
# 4: 335208 => 340415
# 5: 340416 => 420207
# 6: 420208 => 499999
#
#    1   2   3   4   5   6
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-3b164cef893b> in <module>
#       4 print_id = False # The shape id will be printed
#       5 color_pallete = 1 # 'Purples'
# ----> 6 plot_regiones_data(sf, 'Valores de los arriendos de departamento por regiones (datos Yapo.cl)', regiones, data, color_pallete, print_id)
#
# <ipython-input-18-4967b5d9a310> in plot_regiones_data(sf, title, regiones, data, color, print_id)
#      10     for i in regiones:
#      11         #print(i)
# ---> 12         id = df[df.NOMBRE == i].index.get_values()[0]
#      13         region_id.append(id)
#      14
#
# AttributeError: 'Int64Index' object has no attribute 'get_values'

# %%
import geopandas as gpd
df_geo = gpd.read_file(shp_path)
fig, ax = plt.subplots(figsize=(10,10))
df.plot(ax=ax,color='white', edgecolor='black')
ax.set_aspect('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-2ca88bb600e3> in <module>
#       2 df_geo = gpd.read_file(shp_path)
#       3 fig, ax = plt.subplots(figsize=(10,10))
# ----> 4 df.plot(ax=ax,color='white', edgecolor='black')
#       5 ax.set_aspect('equal')
#       6 plt.show()
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     267     def generate(self):
#     268         self._args_adjust()
# --> 269         self._compute_plot_data()
#     270         self._setup_subplots()
#     271         self._make_plot()
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     416         # no non-numeric frames or series allowed
#     417         if is_empty:
# --> 418             raise TypeError("no numeric data to plot")
#     419
#     420         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot

# %%
df_geo
# Out:
#    ID_2002                                   NOMBRE  \
# 0       15                       Arica y Parinacota
# 1       01                                 Tarapaca
# 2       02                              Antofagasta
# 3       03                                  Atacama
# 4       04                                 Coquimbo
# 5       05                               Valparaiso
# 6       13                Metropolitana de Santiago
# 7       06      Libertador Gral. Bernardo O'Higgins
# 8       07                                    Maule
# 9       08                                   Biobio
# 10      09                             La Araucania
# 11      14                                 Los Rios
# 12      10                                Los Lagos
# 13      11  Aisen del Gral. Carlos Ibañez del Campo
# 14      12     Magallanes y de la Antartica Chileno
#
#                                                                                                                                                                                                                                                                                                        geometry
# 0   POLYGON ((-70.26623 -19.19022, -70.27196 -19.18892, -70.27457 -19.18345, -70.27760 -19.17672, -70.27403 -19.17129, -70.27533 -19.16751, -70.27352 -19.16249, -70.27084 -19.15789, -70.27079 -19.15119, -70.26988 -19.14784, -70.26985 -19.14364, -70.27904 -19.13351, -70.27900 -19.12890, -70.28513 -19...
# 1   POLYGON ((-70.28617 -19.22897, -70.13096 -19.15446, -70.09897 -19.11888, -70.00240 -19.08001, -69.99822 -19.07553, -69.98297 -19.06716, -69.98058 -19.06447, -69.97789 -19.06327, -69.97519 -19.06536, -69.96353 -19.05969, -69.95636 -19.05341, -69.95217 -19.05042, -69.94560 -19.04892, -69.94111 -19...
# La Araucania               POLYGON ((-71.04429 -38.12317, -71.02934 -38.13412, -71.02774 -38.13919, -71.02427 -38.14479, -71.02480 -38.14933, -71.02080 -38.15066, -71.01787 -38.15040, -71.01039 -38.15333, -71.01066 -38.16081, -71.00932 -38.16267, -70.99705 -38.16934, -70.99625 -38.17175, -70.99651 -38.17682, -70.99491 -38...
#
#                            precio_prom
# Antofagasta                     500000
# Valparaiso                      330000
# Metropolitana de Santiago       340416
# La Araucania                    320000

# %%
import geopandas as gpd
#df_geo = gpd.read_file(shp_path)
fig, ax = plt.subplots(figsize=(10,20))
result.plot(ax=ax,edgecolor='black',column='precio_prom', cmap='OrRd',legend=True,
        legend_kwds={'label': "Valor arriendo departamento (datos Yapo.cl)",'orientation': "horizontal"})
ax.set_aspect('equal')
plt.show()

# %%
cursor.execute("USE Yapo2")
sql="Select group_CONCAT(descripcion SEPARATOR ' ') as descripcion ,categoria from anuncio group by categoria ORDER BY categoria Asc;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1
# Out:
#                                                                                                                                                                                                                                                                                                     descripcion  \
# 0   usado pero están en buen estado 973275970 Caja Automatica de Kia Sorento 4x4 2004 usada funcionando turbo toyota Hi lux 3.0 diesel turbo toyota Hi lux 3.0 diesel venden 5 neumáticos tubulares 235/75 r17.5 de similares características en 200.000 los 5 neumáticos Bomba de dirección $ 80.000Repuest...
# 1                                      linda montura cordillerana de 19 pulgadas, casco río bueno, incluye estribos y cinchas .Consultas llamar al 984264722 (solo llamados) por cumplir 6 años muy manso y de muchas condiciones está a punto de topiar interesados comunicarse al 978639063 ubicado en paine.
# 2   bien Ubicada cerca de U Católica y TUE centro comercial, mall, casa amplia , con bosca y leñera, amplio patio, terraza techada ,riego, cocina amoblada, piso cerámica en living comedor, piso flotante en dormitorios. urgente persona sola urgente persona sola arrienda casa habitación pequeña . Para...
# 3   local 250 m2 frente a Metro Plaza Puente Alto, gran afluencia de público, renta rebajada hasta 2021 a UF 150, respeto del periodo UF 220, oportunidad local 250 m2 frente a Metro Plaza Puente Alto, gran afluencia de público, renta rebajada hasta 2021 a UF 150, respeto del periodo UF 220, oportunidad
# 4   Depto 2 dormitorios, Las Rejas 65, Est. Central.Valor Arriendo : 330.000, damos la facilidad de cancelar $300.000 los 6 primeros meses.Directo con el dueño, SIN COMISIÖN, la garantía se puede cancelar en  cuotas.Requisitos:-3 Últimas liquidaciones-Cédula de Identidad- No tener Dicom- Aval o Cheq...
# 5   DE OFICINAS EN PROVIDENCIA Contamos con todos los resguardos sanitarios necesarios para cuidar la salud de nuestros arrendatarios! Edificio de 4 pisos ubicado en Román Díaz 117, a pasos del Metro Salvador y Manuel Montt. Un espacio con baja densidad de personas para resguardar la salud de todos!...
# 6   pieza en la las salinas Talcahuano , Vivo solo e incluye, luz, agua, gas , internet, cable, la casa tiene lavadora, secadora, cocina full, estufa.La casa tiene patio y estacionamiento Buen ambiente y comodidad, la calle es super central y pasan micros al frente, hay supermercados cerca. Cobro me...
# 7   francés restaurado por max bangert restaurador museo Santa Cruz antigua Marca Admiral modelo 5A33 año 1953 funcionando con reloj alarma y radio AM, americana con transformador incluido encontrado en casa antigua, autor desconocido pintada en oleo original sin marco, año aproximado 1800-1900, 30x...
Agrado 5.000 mts2 Rol Propio, ubicadas en la Comuna de Paredones, a 8 minutos de Bucalemu, 25 minutos de Boyeruca y 40 minutos de Pichilemu. Factibilidad de luz y agua. de Agrado 5.000 mts2 Rol Propio, ubicadas en la Comuna de Paredones, a 8 minutos de Bucalemu, 25 minutos de Boyeruca y 40 mi...
# 39                                                                                                                                            ( número 24) todo en 20 mil pesos...solo un uso ...para ninñito de 1 a 2 añitos. ( número 24) todo en 20 mil pesos...solo un uso ...para ninñito de 1 a 2 añitos.
#
#                                  categoria
# 0       Accesorios y piezas para vehículos
# 1                Animales y sus accesorios
# 2                          Arriendo - Casa
# 3        Arriendo - Comercial e industrial
# 4                  Arriendo - Departamento
# 5                       Arriendo - Oficina
# 6                         Arriendo - Pieza
# 7         Arte, antigüedades y colecciones
# 8            Audio, TV, video y fotografía
# 9                  Autos, camionetas y 4x4
# 10               Barcos, lanchas y aviones
# 11       Bicicletas, ciclismo y accesorios
# 12          Bolsos, bisutería y accesorios
# 13              Buses, camiones y furgones
# 14                                 Calzado
# 15       Celulares, teléfonos y accesorios
# 16           Coches y artículos infantiles
# 17               Computadores y accesorios
# 18      Consolas, videojuegos y accesorios
# 19         Deportes, gimnasia y accesorios
# 20                       Electrodomésticos
# 21     Instrumentos musicales y accesorios
# 22       Jardín, herramientas y exteriores
# 23                                Juguetes
# 24                       Libros y revistas
# 25                        Moda y vestuario
# 26                                   Motos
# 27                                 Muebles
# 28         Música y películas (DVDs, etc.)
# 29     Negocios, maquinaria y construcción
# 30                       Ofertas de empleo
# 31               Otros artículos del hogar
# 32                         Otros vehículos
# 33                         Salud y belleza
# 34                               Servicios
# 35                            Vendo - Casa
# 36                    Vendo - Departamento
# 37  Vendo - Estacionamiento, bodega u otro
# 38                         Vendo - Terreno
# 39           Vestuario futura mamá y niños

# %%
#!python -m spacy download es_core_news_sm
# Out:
# Requirement already satisfied: es_core_news_sm==2.3.1 from https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-2.3.1/es_core_news_sm-2.3.1.tar.gz#egg=es_core_news_sm==2.3.1 in /home/felipe/miniconda3/lib/python3.8/site-packages (2.3.1)
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /home/felipe/miniconda3/lib/python3.8/site-packages (from es_core_news_sm==2.3.1) (2.3.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/felipe/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (1.0.2)
# Requirement already satisfied: thinc==7.4.1 in /home/felipe/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (7.4.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /home/felipe/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (0.7.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/felipe/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (2.23.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/felipe/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (1.19.1)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /home/felipe/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (0.4.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /home/felipe/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (1.0.2)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /home/felipe/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (1.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/felipe/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (3.0.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /home/felipe/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (0.9.6)
# Requirement already satisfied: setuptools in /home/felipe/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (46.4.0.post20200518)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/felipe/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (4.46.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/felipe/miniconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (2.0.3)
# Requirement already satisfied: idna<3,>=2.5 in /home/felipe/miniconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/felipe/miniconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/felipe/miniconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/felipe/miniconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (1.25.8)
# ✔ Download and installation successful
# You can now load the model via spacy.load('es_core_news_sm')

# %%
import spacy 
from collections import Counter
nlp = spacy.load("es_core_news_sm")
spacy_stopwords = spacy.lang.es.stop_words.STOP_WORDS
pd.options.display.max_colwidth = 300

# %%
df1
# Out:
#                                                                                                                                                                                                                                                                                                     descripcion  \
# 0   usado pero están en buen estado 973275970 Caja Automatica de Kia Sorento 4x4 2004 usada funcionando turbo toyota Hi lux 3.0 diesel turbo toyota Hi lux 3.0 diesel venden 5 neumáticos tubulares 235/75 r17.5 de similares características en 200.000 los 5 neumáticos Bomba de dirección $ 80.000Repuest...
# 1                                      linda montura cordillerana de 19 pulgadas, casco río bueno, incluye estribos y cinchas .Consultas llamar al 984264722 (solo llamados) por cumplir 6 años muy manso y de muchas condiciones está a punto de topiar interesados comunicarse al 978639063 ubicado en paine.
# 2   bien Ubicada cerca de U Católica y TUE centro comercial, mall, casa amplia , con bosca y leñera, amplio patio, terraza techada ,riego, cocina amoblada, piso cerámica en living comedor, piso flotante en dormitorios. urgente persona sola urgente persona sola arrienda casa habitación pequeña . Para...
# 3   local 250 m2 frente a Metro Plaza Puente Alto, gran afluencia de público, renta rebajada hasta 2021 a UF 150, respeto del periodo UF 220, oportunidad local 250 m2 frente a Metro Plaza Puente Alto, gran afluencia de público, renta rebajada hasta 2021 a UF 150, respeto del periodo UF 220, oportunid
# 17  Repuesto. No enciende . vende lenovo para repuesto todo lo que se ve en la imagen. por renovación Notebook Hp Windws 10 -Procesador: Intel(R) Celeron(R) CPU N2840-2,16GHz -Memoria RAM 4Gb-Sistema operativo de 64bits -Tiene bluetooth y conexion a wifi funcionando -Pantalla, teclado, touchpad y ca...
# 18  Arkham knight: 15.000Uncharted 4 : 10.000 South park retaguardia en peligro: 15.000Resident evil revelations 2 : 15.000Assassin's crees unity: 10.000. Battlefield hardline: 12.000Acepto 70 mil por todos dos controles Nintendo Wii U, cargador de corriente y volante para Mario kart. Todo junto, y ...
# 19  botas de snowboard mujer marca Nitro talla US 7 women (38)! Excelente estado, solo una temporada de uso! botas de snowboard mujer marca Nitro talla US 7 women (38)! Excelente estado, solo una temporada de uso! perfecto funcionamiento y  buenas condiciones. tobillera y muñequera para hacer ejerci...
# 20  vende cocina a gas funcionando súper bien.ubicado en Calbuco $50.000 hablar al wsp +56952002899.- fensa 16kg con presecado llegar y usar interesados llamar 956640386 venden los dos juntos!Cualquier cosa comunicarse al numero+56996313525 más esqueleto mesedora , todo por cambio de residencia vend...
# 21                                                                                                                                                                                              consulta para probar escribir por whatsapp +56981299878 consulta para probar escribir por whatsapp +56981299878
# 22  $4500 cada una.  Agapantos con flores azules chicos $1000 Yuca $5000 parrillas baratas totalmente desmontable están nuevas son hechas de tambor de 208 litros tumbonas impecables.san alfonso del mar.vendo o permuto algo interesante. terrazas dos piezas incluidos 6 cojines grandes de respaldo.con ...
# 23  gigante Mide aprox 1.65 está en excelente estado prácticamente nuevo gigante Mide aprox 1.65 está en excelente estado prácticamente nuevo no se modelo no sé si tiene otros accesorios pero solo se vende lo de la foto en buen estadoDos cargadores de 6balas cada una sin balas sin caja, sin manual, ...
# 24  usado, original, de tapa dura, tiene 255 páginas y es primera edición de 1967 de The walking dead, original y en buen estado varias libros en excelente estado. Consulte por precios. Aprox entre 7000 y 10000Tengo libros de niños, adolescentes y en inglés varias libros en excelente estado. Consult...
# 25  marca Falcone gris, poco uso, ninguna peladura. Único detalle, en la cartera derecha el cierre no tiene marca. Cabe mencionar todos los cierres funcionan bien. croptop , elásticado sirve hasta talla M/L croptop , elásticado sirve hasta talla M/L minnie talla M/L nuevo cuerina nueva, talla M y L ...
# 26                                  vende moto al dia buen cuidada mantenciones al dia Inscrita a mi nombre transferible año 2019 interesado wsp +56958552048 moto con algo de pie y el resto en cuotas puedo firmar pagare en Notaria moto con algo de pie y el resto en cuotas puedo firmar pagare en Notaria
# 27  buenas condiciones escritorio , mesa de vidrio grueso . Ancho 60 cmLargo 1.20 altura 74cm en perfecto estado , con semanas de uso en perfecto estado , con semanas de uso metálico con vidrioLo publico barato, NO hago rebaja de precio vende galón de 15 kilos a 25000 y la jaula 8000 todo en 30000 B...
# 28                                                                       vende vinilo (Alemania, 1985). Primera edición. Incluye inserto. Carátula con iniciales "AF" en relieve. Disco excelente. (Alemania, 1985). Primera edición. Incluye inserto. Carátula con iniciales "AF" en relieve. Disco excelente.
# 29      Hp Designjet T-830 36" Multifuncional Impecable -Imprime, escanea y fotocopia Full Color-Plotter rápido para Planos y económico-Probado y Funcionando-Traslado e instalación dentro de Stgo-Incluye Mantención reciente-Cabezal y tintas operativas-Incluye rollo de papel VALOR OFERTA $2.100.000 NETO
# 30  Motorista part time 30 horas para locales ubicados en :Mizu la DehesaMizu ChicureoMizu Las CondesMizu PeñalolénMizu HuechurabaSe paga por envio $650.Con moto propia, buena disposición Motorista part time 30 horas para locales ubicados en :Mizu la DehesaMizu ChicureoMizu Las CondesMizu PeñalolénM...
# 31  de navidad 'Cypress tree',blanco,  usado como nuevo. 62 cms. Incluye 2 cajas de adornos. Retiro en domicilio por estar sin uso sagrado de 60cm y 80cm de altura, para colgarhecho en madera reciclada precio:60cm $1450080cm $19500Envio a convenirChilexpressMario +56 9 6294 3326 wassap 64055695 DE A...
# 32                                  SEMI REMOLQUEMARCA: FLORESMODELO: FERRASAÑO: 2014CARGA: 35 TON.DOCUMENTACIÓN AL DÍAValor : 7.900.000 IVA INCLUIDOCONTACTAR: 963482830 SEMI REMOLQUEMARCA: FLORESMODELO: FERRASAÑO: 2014CARGA: 35 TON.DOCUMENTACIÓN AL DÍAValor : 7.900.000 IVA INCLUIDOCONTACTAR: 963482830
# 33   corporal nueva, sin caja incluye exfoliante y gel de aplicación. en perfecto estado quemadoras de grasa y reductora de talla tallas XS S M L XL XXL   +56971629770 dudas a mi wsp Reactivas ACCU-CHEK Performa, caja de 50 unidades, vencimiento desde Noviembre 2020 en adelante, precio $ 10.000/unid...
# 34  tratamiento ceramico Lavado detallado. Descontaminado de barniz. Secado con microfibras. Corrección de barniz en un paso. Sellado cerámico con dureza 9h duracion 12 meses. Sellado de plasticos exteriores. Acondicionado de cubiertas.SIN CARGOtratamiento de ozono interior, que mata virus bacterias...
# 35  vende Casa en Molina Villa Bicentenario de 1 piso, 2 Dormitorios, baño, cocina. con amplias posibilidades de ampliarse, Casa esquinaLocomocion, Jardin, cerca del Centro+56 9 9440 0508 vende parcela 10.800 mt2, con dos casas la blanca deb80 mt2 dos dormitorios 1 baño, cocina independiente, 2da. C...
# 36  completo (con 7 departamentos)Distancias:200 m club español y centro comercial 500 m colegio mackay 800 m universidad1000 m playas reñacaCuenta con 2 tasaciones bancarias de 13.800 UF y 13.260 UF (hace menos de 2 meses)7 cocinas 9 baños12 dormitorios7 estarSe publicó portada de tasación bancaria...
# 37  Sepultura de Parque El Sendero. Manzana Y2.Lo compré inicialmente para un familiar que finalmente quedó sepultado en otro lugar. Vivo en Santiago así es que no haré uso de este terreno.La sepultura tiene espacio para dos cuerpos, y a futuro, podría ser 1 cuerpo y 3 reducciones.Las mantenciones a...
# 38  de Agrado 5.000 mts2 Rol Propio, ubicadas en la Comuna de Paredones, a 8 minutos de Bucalemu, 25 minutos de Boyeruca y 40 minutos de Pichilemu. Factibilidad de luz y agua. de Agrado 5.000 mts2 Rol Propio, ubicadas en la Comuna de Paredones, a 8 minutos de Bucalemu, 25 minutos de Boyeruca y 40 mi...
# 39                                                                                                                                            ( número 24) todo en 20 mil pesos...solo un uso ...para ninñito de 1 a 2 añitos. ( número 24) todo en 20 mil pesos...solo un uso ...para ninñito de 1 a 2 añitos.
#
#                                  categoria
# 0       Accesorios y piezas para vehículos
# 1                Animales y sus accesorios
# 2                          Arriendo - Casa
# 3        Arriendo - Comercial e industrial
# 4                  Arriendo - Departamento
# 5                       Arriendo - Oficina
# 6                         Arriendo - Pieza
# 7         Arte, antigüedades y colecciones
# 8            Audio, TV, video y fotografía
# 9                  Autos, camionetas y 4x4
# 10               Barcos, lanchas y aviones
# 11       Bicicletas, ciclismo y accesorios
# 12          Bolsos, bisutería y accesorios
# 13              Buses, camiones y furgones
# 14                                 Calzado
# 15       Celulares, teléfonos y accesorios
# 16           Coches y artículos infantiles
# 17               Computadores y accesorios
# 18      Consolas, videojuegos y accesorios
# 19         Deportes, gimnasia y accesorios
# 20                       Electrodomésticos
# 21     Instrumentos musicales y accesorios
# 22       Jardín, herramientas y exteriores
# 23                                Juguetes
# 24                       Libros y revistas
# 25                        Moda y vestuario
# 26                                   Motos
# 27                                 Muebles
# 28         Música y películas (DVDs, etc.)
# 29     Negocios, maquinaria y construcción
# 30                       Ofertas de empleo
# 31               Otros artículos del hogar
# 32                         Otros vehículos
# 33                         Salud y belleza
# 34                               Servicios
# 35                            Vendo - Casa
# 36                    Vendo - Departamento
# 37  Vendo - Estacionamiento, bodega u otro
# 38                         Vendo - Terreno
# 39           Vestuario futura mamá y niños

# %%
x=[]
for i in range(df1.index.size):
    desc=nlp(df1.iloc[i].descripcion)
    words = [token.text for token in desc if token.is_stop != True and token.is_punct != True and token.pos_ != 'AUX' and token.pos_ !='ADP' and token.pos_ !='NUM' and token.pos_ !='CCONJ' and token.pos_!='SYM']
    Word_freq = Counter(words)
    common_words = Word_freq.most_common(10)
    x+=[common_words]

# %%
df1['mas comunes']=x

# %%
df1
# Out:
#                                                                                                                                                                                                                                                                                                     descripcion  \
# 0   usado pero están en buen estado 973275970 Caja Automatica de Kia Sorento 4x4 2004 usada funcionando turbo toyota Hi lux 3.0 diesel turbo toyota Hi lux 3.0 diesel venden 5 neumáticos tubulares 235/75 r17.5 de similares características en 200.000 los 5 neumáticos Bomba de dirección $ 80.000Repuest...
# 1                                      linda montura cordillerana de 19 pulgadas, casco río bueno, incluye estribos y cinchas .Consultas llamar al 984264722 (solo llamados) por cumplir 6 años muy manso y de muchas condiciones está a punto de topiar interesados comunicarse al 978639063 ubicado en paine.
# 2   bien Ubicada cerca de U Católica y TUE centro comercial, mall, casa amplia , con bosca y leñera, amplio patio, terraza techada ,riego, cocina amoblada, piso cerámica en living comedor, piso flotante en dormitorios. urgente persona sola urgente persona sola arrienda casa habitación pequeña . Para...
# 3   local 250 m2 frente a Metro Plaza Puente Alto, gran afluencia de público, renta rebajada hasta 2021 a UF 150, respeto del periodo UF 220, oportunidad local 250 m2 frente a Metro Plaza Puente Alto, gran afluencia de público, renta rebajada hasta 2021 a UF 150, respeto del periodo UF 220, oportunidad
# 4   Depto 2 dormitorios, Las Rejas 65, Est. Central.Valor Arriendo : 330.000, damos la facilidad de cancelar $300.000 los 6 primeros meses.Directo con el dueño, SIN COMISIÖN, la garantía se puede cancelar en  cuotas.Requisitos:-3 Últimas liquidaciones-Cédula de Identidad- No tener Dicom- Aval o Cheq...
# 5   DE OFICINAS EN PROVIDENCIA Contamos con todos los resguardos sanitarios necesarios para cuidar la salud de nuestros arrendatarios! Edificio de 4 pisos ubicado en Román Díaz 117, a pasos del Metro Salvador y Manuel Montt. Un espacio con baja densidad de personas para resguardar la salud de todos!...
# 6   pieza en la las salinas Talcahuano , Vivo solo e incluye, luz, agua, gas , internet, cable, la casa tiene lavadora, secadora, cocina full, estufa.La casa tiene patio y estacionamiento Buen ambiente y comodidad, la calle es super central y pasan micros al frente, hay supermercados cerca. Cobro me...
# 7   francés restaurado por max bangert restaurador museo Santa Cruz antigua Marca Admiral modelo 5A33 año 1953 funcionando con reloj alarma y radio AM, americana con transformador incluido encontrado en casa antigua, autor desconocido pintada en oleo original sin marco, año aproximado 1800-1900, 30x...
# 8   a la venta:Edición especial limitada de 350 Andromeda con acabado Cerakote ™. Diseñado y ensamblado a mano en Portland, Oregon, EE. UU.Lean reseñas y comentarios muy buenos audífonos solo para entendidos.Precio: $ 700.000 8 meses de uso. Vendo Par De Parlantes Sony, Excelente Estado y Calidad De...
# 9   vehículo en buen estado, vendo por renovación. vende kia avella año 2000 1.3 con 238.900 kms.sin partes ni deudas,permiso de circulación al dia al igual que el seguro,revisión tecnica pendiente solo por la contingencia,de todas formas está prorrogada hasta noviembre,se vende por renovación,detal...
# 10                                                                                                                                                                                                                                                   motor fuera de borda 200hp que este en optimas condiciones
# 11  bicicleta oxford mujer aro 24 en perfecto estado , con todos sus accesorios. Llamar verdaderos interesados. bicicle
( número 24) todo en 20 mil pesos...solo un uso ...para ninñito de 1 a 2 añitos. ( número 24) todo en 20 mil pesos...solo un uso ...para ninñito de 1 a 2 añitos.
#
#                                  categoria  \
# 0       Accesorios y piezas para vehículos
# 1                Animales y sus accesorios
# 2                          Arriendo - Casa
# 3        Arriendo - Comercial e industrial
# 4                  Arriendo - Departamento
# 5                       Arriendo - Oficina
# 6                         Arriendo - Pieza
# 7         Arte, antigüedades y colecciones
# 8            Audio, TV, video y fotografía
# 9                  Autos, camionetas y 4x4
# 10               Barcos, lanchas y aviones
# 11       Bicicletas, ciclismo y accesorios
# 12          Bolsos, bisutería y accesorios
# 13              Buses, camiones y furgones
# 14                                 Calzado
# 15       Celulares, teléfonos y accesorios
# 16           Coches y artículos infantiles
# 17               Computadores y accesorios
# 18      Consolas, videojuegos y accesorios
# 19         Deportes, gimnasia y accesorios
# 20                       Electrodomésticos
# 21     Instrumentos musicales y accesorios
# 22       Jardín, herramientas y exteriores
# 23                                Juguetes
# 24                       Libros y revistas
# 25                        Moda y vestuario
# 26                                   Motos
# 27                                 Muebles
# 28         Música y películas (DVDs, etc.)
# 29     Negocios, maquinaria y construcción
# 30                       Ofertas de empleo
# 31               Otros artículos del hogar
# 32                         Otros vehículos
# 33                         Salud y belleza
# 34                               Servicios
# 35                            Vendo - Casa
# 36                    Vendo - Departamento
# 37  Vendo - Estacionamiento, bodega u otro
# 38                         Vendo - Terreno
# 39           Vestuario futura mamá y niños
#
#                                                                                                                                                             mas comunes
# 0                                          [(diesel, 4), (whatsapp, 3), (numero, 3), (+56, 3), (turbo, 2), (toyota, 2), (Hi, 2), (lux, 2), (neumáticos, 2), (Bomba, 2)]
# 1                        [(linda, 1), (montura, 1), (cordillerana, 1), (pulgadas, 1), (casco, 1), (río, 1), (incluye, 1), (estribos, 1), (cinchas, 1), (.Consultas, 1)]
# 2   [(dormitorios, 3), (persona, 3), (casa, 2), (cocina, 2), (piso, 2), (living, 2), (comedor, 2), (urgente, 2), (baños, 2), (cocina-comedor-livingestacionamiento, 2)]
# 3                                             [(UF, 4), (local, 2), (m2, 2), (frente, 2), (Metro, 2), (Plaza, 2), (Puente, 2), (Alto, 2), (afluencia, 2), (público, 2)]
# 4                                        [(dormitorios, 3), ( , 3), (arriendo, 3), (cancelar, 2), (Quinta, 2), (Normal, 2), (Mes, 2), (Depto, 1), (Rejas, 1), (Est, 1)]
# 5       [(salud, 4), (resguardos, 3), (sanitarios, 3), (cuidar, 3), (arrendatarios, 3), (OFICINAS, 2), (PROVIDENCIA, 2), (Contamos, 2), (necesarios, 2), (Edificio, 2)]
# 6                                         [(casa, 2), (pieza, 1), (salinas, 1), (Talcahuano, 1), (Vivo, 1), (incluye, 1), (luz, 1), (agua, 1), (gas, 1), (internet, 1)]
# 7                                [(antigua, 3), (año, 3), (encontrado, 2), (casa, 2), (autor, 2), (desconocido, 2), (pintada, 2), (oleo, 2), (original, 2), (marco, 2)]
# 8                                        [( , 3), (TV, 2), (venta, 1), (Edición, 1), (especial, 1), (limitada, 1), (Andromeda, 1), (acabado, 1), (Cerakote, 1), (™, 1)]
# 9                                  [(año, 6), (auto, 3), (full, 3), (vendo, 2), (renovación, 2), (vende, 2), (equipo, 2), (excelente, 2), (dueño, 2), (conversable, 2)]
# 28                               [(Alemania, 2), (1985, 2), (edición, 2), (Incluye, 2), (inserto, 2), (Carátula, 2), (iniciales, 2), (AF, 2), (relieve, 2), (Disco, 2)]
# 29                 [(Hp, 1), (Designjet, 1), (T-830, 1), (Multifuncional, 1), (Impecable, 1), (escanea, 1), (fotocopia, 1), (Full, 1), (Color-Plotter, 1), (rápido, 1)]
# 30              [(Motorista, 2), (part, 2), (time, 2), (locales, 2), (ubicados, 2), (Mizu, 2), (DehesaMizu, 2), (ChicureoMizu, 2), (CondesMizu, 2), (PeñalolénMizu, 2)]
# 31                                             [(cm, 5), ($, 3), (navidad, 2), (cms, 2), (Cypress, 1), (tree',blanco, 1), ( , 1), (usado, 1), (Incluye, 1), (cajas, 1)]
# 32          [(SEMI, 2), (REMOLQUEMARCA, 2), (FLORESMODELO, 2), (FERRASAÑO, 2), (TON.DOCUMENTACIÓN, 2), (DÍAValor, 2), (IVA, 2), (INCLUIDOCONTACTAR, 2), (963482830, 1)]
# 33                     [(caja, 3), (eau, 3), (incluye, 2), (Reactivas, 2), (ACCU-CHEK, 2), (Performa, 2), (unidades, 2), (vencimiento, 2), (Noviembre, 2), (precio, 2)]
# 34                      [(barniz, 4), (Sellado, 4), ($, 4), (autos, 3), (tratamiento, 2), (ceramico, 2), (Lavado, 2), (detallado, 2), (Descontaminado, 2), (Secado, 2)]
# 35                                  [(Casa, 3), (cocina, 3), (mt2, 3), (vende, 2), (baño, 2), (dormitorios, 2), (baños, 2), (Molina, 1), (Villa, 1), (Bicentenario, 1)]
# 36                               [(ubicado, 3), (San, 3), (UF, 2), (vende, 2), (Departamento, 2), (comuna, 2), (Joaquin, 2), (dormitorio, 2), (amplio, 2), (closet, 2)]
# 37              [(terreno, 2), (Sepultura, 1), (Parque, 1), (Sendero, 1), (Manzana, 1), (compré, 1), (inicialmente, 1), (familiar, 1), (finalmente, 1), (sepultado, 1)]
# 38                              [(minutos, 12), (Bucalemu, 4), (Boyeruca, 4), (Pichilemu, 4), (playa, 4), (Agrado, 2), (mts2, 2), (Rol, 2), (ubicadas, 2), (Comuna, 2)]
# 39                                                                                                                 [(número, 2), (pesos, 2), (ninñito, 2), (añitos, 2)]

# %% [markdown]
# POdemos ver que algunos anuncios se repiten pues algunos usuarios publican mas de una vez el mismo anuncio.

# %%
sql="select  vendedor.nombre_region,group_concat(descripcion ORDER BY  vendedor.codigo_region asc SEPARATOR' ') as descripcion from anuncio join vendedor using (id_vendedor)  group by vendedor.nombre_region;"
cursor.execute(sql)
df2 = DataFrame(cursor.fetchall())
df2.columns = cursor.column_names
df2
# Out:
#              nombre_region  \
# 0                    Aisén
# 1              Antofagasta
# 2                Araucanía
# 3       Arica & Parinacota
# 4                  Atacama
# 5                   Biobío
# 6                 Coquimbo
# 7                Los Lagos
# 8                 Los Ríos
# 9   Magallanes & Antártica
# 10                   Maule
# 11           Metropolitana
# 12                   Ñuble
# 13               O'Higgins
# 14                Tarapacá
# 15              Valparaíso
#
#                                                                                                                                                                                                                                                                                                     descripcion
# 0                                                                                                                                                                                                                     calzados Artesanal solo CUERO nacional , modelos de fotos y tenemos más de hombre y mujer
# 1   buenas condiciones mueble para guardar artículos de escritorios , libros , cuaderno , etc Ancho 40 cmLargo 29 cm Altura 100 cm buenas condiciones escritorio , mesa de vidrio grueso . Ancho 60 cmLargo 1.20 altura 74cm dos controles Nintendo Wii U, cargador de corriente y volante para Mario kart. ...
# 2   sprinter 15+1 full, neumáticos nuevos,mantenciones con repuestos originales. 2 dueños, precio conversable sprinter 15+1 full, neumáticos nuevos,mantenciones con repuestos originales. 2 dueños, precio convers
EMI REMOLQUEMARCA: FLORESMODELO: FERRASAÑO: 2014CARGA: 35 TON.DOCUMENTACIÓN AL DÍAValor : 7.900.000 IVA INCLUIDOCONTACTAR: 963482830 SEMI REMOLQUEMARCA: FLORESMODELO: FERRASAÑO: 2014CARGA: 35 TON.DOCUMENTACIÓN AL DÍAValor : 7.90...

# %%
y=[]
for i in range(df2.index.size):
    desc=nlp(df2.iloc[i].descripcion)
    words = [token.text for token in desc if token.is_stop != True and token.is_punct != True and token.pos_!='SYM' and token.pos_ != 'AUX' and token.pos_ !='ADP' and token.pos_ !='NUM' and token.pos_ !='CCONJ' ]
    Word_freq = Counter(words)
    common_words = Word_freq.most_common(1)
    y+=[common_words]

# %%
df2['mas comunes']=y

# %%
df2
# Out:
#              nombre_region  \
# 0                    Aisén
# 1              Antofagasta
# 2                Araucanía
# 3       Arica & Parinacota
# 4                  Atacama
# 5                   Biobío
# 6                 Coquimbo
# 7                Los Lagos
# 8                 Los Ríos
# 9   Magallanes & Antártica
# 10                   Maule
# 11           Metropolitana
# 12                   Ñuble
# 13               O'Higgins
# 14                Tarapacá
# 15              Valparaíso
#
#                                                                                                                                                                                                                                                                                                     descripcion  \
# 0                                                                                                                                                                                                                     calzados Artesanal solo CUERO nacional , modelos de fotos y tenemos más de hombre y mujer
# 1   buenas condiciones mueble para guardar artículos de escritorios , libros , cuaderno , etc Ancho 40 cmLargo 29 cm Altura 100 cm buenas condiciones escritorio , mesa de vidrio grueso . Ancho 60 cmLargo 1.20 altura 74cm dos controles Nintendo Wii U, cargador de corriente y volante para Mario kart. ...
# 2   sprinter 15+1 full, neumáticos nuevos,mantenciones con repuestos originales. 2 dueños, precio conversable sprinter 15+1 full, neumáticos nuevos,mantenciones con repuestos originales. 2 dueños, precio conversable plata estrella cadena de 45bo 50 cm.Se entrega en bolsa de organza plata estrella ca...
# 3   ( número 24) todo en 20 mil pesos...solo un uso ...para ninñito de 1 a 2 añitos. ( número 24) todo en 20 mil pesos...solo un uso ...para ninñito de 1 a 2 añitos. vende juego de living buen estado.. detalles solo por el uso.. vende traje de Machona Caporal Sangre Andina, solo se usó los 3 días de...
# 4                                                            toyota aygo pago en efectivo turbo toyota Hi lux 3.0 diesel turbo toyota Hi lux 3.0 diesel Bomba de dirección $ 80.000Repuesto para camioneta Toyota Hilux 3.0 diesel. Bomba de dirección $ 80.000Repuesto para camioneta Toyota Hilux 3.0 diesel.
# 5    vende galón de 15 kilos a 25000 y la jaula 8000 todo en 30000 en perfecto estado , con semanas de uso en perfecto estado , con semanas de uso marca Falcone gris, poco uso, ninguna peladura. Único detalle, en la cartera derecha el cierre no tiene marca. Cabe mencionar todos los cierres funcionan...
# 6   tratamiento ceramico Lavado detallado. Descontaminado de barniz. Secado con microfibras. Corrección de barniz en un paso. Sellado cerámico con dureza 9h duracion 12 meses. Sellado de plasticos exteriores. Acondicionado de cubiertas.SIN CARGOtratamiento de ozono interior, que mata virus bacterias...
# 7   nombre es Pablo Castillo, Estudiante de Música y Composición de la Universidad UNIACC de Santiago, Toco guitarra eléctrica hace aproximadamente 10 años, Busco alumnos de nivel básico e intermedio que busquen aprender desde 0 y/o mejorar sus capacidades dentro de este maravilloso instrumento que ...
# 8                                                                                                                                                vende lenovo para repuesto todo lo que se ve en la imagen. venden 5 neumáticos tubulares 235/75 r17.5 de similares características en 200.000 los 5 neumáticos
# 9   juego de sofá cama + 2 poltronas en PERFECTO ESTADO. Cero detalles. Vendo por falta de espacio. comprar 2 bancos o sillas para bar en buen estado de no mas de 65 cm de alto fotos y precios al watsap +56959027638 Adidas Skateboarding 3MC Vulc x Mike Judge y suaves, botines de taco bicicleta Bmx m...
# 10  metálico con vidrioLo publico barato, NO hago rebaja de precio fensa 16kg con presecado llegar y usar interesados llamar 956640386 Repuesto. No enciende . vende Casa en Molina Villa Bicentenario de 1 piso, 2 Dormitorios, baño, cocina. con amplias posibilidades de ampliarse, Casa esquinaLocomocio...
# 11  Vendo Par De Parlantes Sony, Excelente Estado y Calidad De Sonido apuro liquido Led 3D Samsung , está impecable y con muy poco uso.Entradas para TV abierta norma digital , cable, rca , hdmi y usbPrecio único  $130.000NO ES SMART TV  ....  ¡¡ ES 3D !! a la venta:Edición especial limitada de 350 A...
# 12                                                                                    (Alemania, 1985). Primera edición. Incluye inserto. Carátula con iniciales "AF" en relieve. Disco excelente. (Alemania, 1985). Primera edición. Incluye inserto. Carátula con iniciales "AF" en relieve. Disco excelente.
# 13  solo una postura dama color verde muzgo talla 42, muy liviana, para la temporada, consultas x whatsaap dama color verde muzgo talla 42, muy liviana, para la temporada, consultas x whatsaap de Agrado 5.000 mts2 Rol Propio, ubicadas en la Comuna de Paredones, a 8 minutos de Bucalemu, 25 minutos de...
# 14  minnie talla M/L nuevo estanpado, talla M nuevo cuerina nueva, talla M y L croptop , elásticado sirve hasta talla M/L croptop , elásticado sirve hasta talla M/L supera carga rápida original para huawei mate 20 pro velocidad de 9vatios consultas inbox o WhatsApp +56963300765 supera carga rápida o...
# 15  Botas de cuero nacional forradas en Térmico . Modelos exclusivos . SEMI REMOLQUEMARCA: FLORESMODELO: FERRASAÑO: 2014CARGA: 35 TON.DOCUMENTACIÓN AL DÍAValor : 7.900.000 IVA INCLUIDOCONTACTAR: 963482830 SEMI REMOLQUEMARCA: FLORESMODELO: FERRASAÑO: 2014CARGA: 35 TON.DOCUMENTACIÓN AL DÍAValor : 7.90...
#
#           mas comunes
# 0     [(calzados, 1)]
# 1        [(vende, 4)]
# 2       [(precio, 4)]
# 3       [(número, 2)]
# 4       [(diesel, 4)]
# 5            [($, 3)]
# 6       [(barniz, 4)]
# 7     [(guitarra, 2)]
# 8   [(neumáticos, 2)]
# 9    [(bicicleta, 2)]
# 10        [(piso, 3)]
# 11           [( , 3)]
# 12    [(Alemania, 2)]
# 13    [(minutos, 12)]
# 14       [(talla, 6)]
# 15        [(SEMI, 2)]

# %% [markdown]
# ### Algunos simbolos no pudieron ser eliminados pero esto solo influye en 2 regiones en este caso

# %% [markdown]
# # PREGUNTA 10

# %% [markdown]
# Para el caso de cuidades que sean decretadas de cuarentena total a partir de una fecha determinada, podriamos hacer scraping el primer dia de dicha cuarentena para saber cuales son los anuncios por categoria mas publicados, para luego compararlos con el ultimo dia de dicha cuarentena. Esto nos podria ayudar a saber que es lo que anuncia la gente en yapo en tiempos de crisis sanitaria y como evoluciona esta entre el final y el inicio de dicha cuarentena, o por otro lado saber si la gente aun estando en cuarentena total hace anuncios mediante yapo ofreciendo productos.
# Otra alternativa seria revisar la media de precios por categoria en una ciudad antes de la cuarentena total y durante esta para ver si hay un alza de precios en esa fecha.
